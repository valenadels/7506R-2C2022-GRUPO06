# %% [markdown]
# # **Trabajo Práctico N°1** Organización de Datos 75.06 2do cuatrimestre 2022
# ## GRUPO 6 - Integrantes: Sofía Javes, Gastón Frenkel, Tomás Emanuel, Valentina Adelsflügel, Víctor Zacarías

# %% [markdown]
# El objetivo principal del trabajo será aplicar técnicas de análisis exploratorio, preprocesamiento
# de datos, agrupamiento, clasificación y regresión sobre el set de datos provisto por la empresa Properati correspondiente a
# anuncios de propiedades en venta de la República Argentina publicados durante el año 2021.

# %% [markdown]
# # Análisis Exploratorio y Preprocesamiento de Datos

# %% [markdown]
# #### Descripción y clasificación de las variables
# Para clasificar cada variable se utilizan los siguientes tipos:
# ![tiposdevar.jpeg](data:image/jpeg;base64,...)
# - id: Identificador del aviso. No es único: si el aviso es actualizado por la inmobiliaria (nueva versión del aviso) se crea un nuevo registro con la misma id pero distintas fechas: de alta y de baja. **(Cualitativa nominal)**
# - start_date: Fecha de alta del aviso. **(Cualitativa ordinal)**
# - end_date: Fecha de baja del aviso. **(Cualitativa ordinal)**
# - created_on: Fecha de alta de la primera versión del aviso. **(Cualitativa ordinal)**
# - place: Campos referidos a la ubicación de la propiedad o del desarrollo.**(Cualitativa nominal)**
# - lat: Latitud. **(Cuantitativa continua)**
# - lon: Longitud. **(Cuantitativa continua)**
# - l1: Nivel administrativo 1: país. **(Cualitativa nominal)**
# - l2: Nivel administrativo 2: usualmente provincia. **(Cualitiva nominal)**
# - l3: Nivel administrativo 3: usualmente ciudad. **(Cualitativa nominal)**
# - l4: Nivel administrativo 4: usualmente barrio. **(Cualitativa nominal)**
# - property: Campos relativos a la propiedad (vacío si el aviso es de un desarrollo/proyecto). **(Cualitativa nominal)**
# - operation: Tipo de operación (Venta, Alquiler). **(Cualitativa nominal)**
# - type: Tipo de propiedad (Casa, Departamento, PH....). **(Cualitativa nominal)**
# - rooms: Cantidad de ambientes (útil en Argentina). **(Cuantitativa discreta)**
# - bedrooms: Cantidad de dormitorios (útil en el resto de los países). **(Cuantitativa discreta)**
# - surface_total: Superficie total en m². **(Cuantitativa continua)**
# - surface_covered: Superficie cubierta en m². **(Cuantitativa continua)**
# - price: Precio publicado en el anuncio. **(Cuantitativa continua)**
# - currency: Moneda del precio publicado. **(Cualitativa nominal)**
# - title: Título del anuncio. **(Cualitativa nominal)**

# %% [markdown]
# Importación de bibliotecas a utilizar.

# %% [markdown]
# En caso de no tener instaladas las bibliotecas ejecutar:

# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /home/tomas/anaconda3/lib/python3.8/site-packages (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/tomas/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/tomas/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /home/tomas/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Requirement already satisfied: numpy in /home/tomas/anaconda3/lib/python3.8/site-packages (1.20.3)
# Requirement already satisfied: seaborn in /home/tomas/anaconda3/lib/python3.8/site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /home/tomas/anaconda3/lib/python3.8/site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: matplotlib>=3.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from seaborn) (3.6.1)
# Requirement already satisfied: pandas>=0.25 in /home/tomas/anaconda3/lib/python3.8/site-packages (from seaborn) (1.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/tomas/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tomas/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (7.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn) (4.37.4)
# Requirement already satisfied: pytz>=2020.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2020.1)
# Requirement already satisfied: six in /home/tomas/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.1->seaborn) (1.15.0)
# Requirement already satisfied: matplotlib in /home/tomas/anaconda3/lib/python3.8/site-packages (3.6.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: numpy>=1.19 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: packaging>=20.0 in /home/tomas/.local/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (7.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tomas/.local/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in /home/tomas/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
pd.options.mode.chained_assignment = None

# %% [markdown]
# Se carga el dataset en un dataframe de Pandas y se realiza una copia para no trabajar sobre el original.

# %%
ds_properati_original = pd.read_csv('properati_argentina_2021.csv')

# %%
ds_properati = ds_properati_original.copy()    
ds_properati.head()
# Out:
#                          id  start_date    end_date  created_on    latitud  \
# 0  XZq2dFGxBiboHY3Bo/tqlw==  2021-09-09  2022-01-27  2021-09-09 -38.957632
# 1  8afoK+yMH/rnnlYiktwgNA==  2021-09-09  2021-10-23  2021-09-09 -34.888878
# 2  iVaG5rBB47dd1Ya4BMXREA==  2021-09-09  2022-03-09  2021-09-09 -32.488717
# 3  QE1QVMWKAHWkd0qT0FtPWA==  2021-09-09  2022-01-27  2021-09-09 -34.900165
# 4  tJ5lSk7IysG/71OGhacNZA==  2021-09-09  2022-01-27  2021-09-09 -38.954528
#
#     longitud    place_l2 place_l3 place_l4 place_l5  place_l6 operation  \
# 0 -68.105443     Neuquén      NaN      NaN      NaN       NaN     Venta
# 1 -56.092368  Montevideo      NaN      NaN      NaN       NaN     Venta
# 2 -58.257499  Entre Ríos      NaN      NaN      NaN       NaN     Venta
# 3 -54.808453   Maldonado      NaN      NaN      NaN       NaN     Venta
# 4 -68.041862     Neuquén      NaN      NaN      NaN       NaN     Venta
#
#   property_type  property_rooms  property_bedrooms  property_surface_total  \
# 0          Casa             6.0                NaN                     NaN
# 1          Casa             4.0                3.0                   193.0
# 2          Casa             NaN                NaN                   110.0
# 3          Casa             NaN                3.0                     NaN
# 4            PH             3.0                2.0                     NaN
#
#    property_surface_covered  property_price property_currency  \
# 0                     206.0             NaN               NaN
# 1                     193.0        390000.0               USD
# 2                      45.0         47000.0               USD
# 3                     180.0        400000.0               USD
# 4                      98.0        102000.0               USD
#
#        property_title
# 0      Casa - Capital
# 1       Casa - Malvín
# 2      Casa - Uruguay
# 3    Casa - El Chorro
# 4  PH - Villa Farrell

# %% [markdown]
# Procedemos a cambiar los nombres de las columnas *place_l2*, *place_l3* y *place_l4* de modo que sean más descriptivas.

# %%
ds_properati.rename(columns = {'place_l2':'provincia', 'place_l3':'ciudad', 'place_l4':'barrio'}, inplace = True)
ds_properati.head(4)
# Out:
#                          id  start_date    end_date  created_on    latitud  \
# 0  XZq2dFGxBiboHY3Bo/tqlw==  2021-09-09  2022-01-27  2021-09-09 -38.957632
# 1  8afoK+yMH/rnnlYiktwgNA==  2021-09-09  2021-10-23  2021-09-09 -34.888878
# 2  iVaG5rBB47dd1Ya4BMXREA==  2021-09-09  2022-03-09  2021-09-09 -32.488717
# 3  QE1QVMWKAHWkd0qT0FtPWA==  2021-09-09  2022-01-27  2021-09-09 -34.900165
#
#     longitud   provincia ciudad barrio place_l5  place_l6 operation  \
# 0 -68.105443     Neuquén    NaN    NaN      NaN       NaN     Venta
# 1 -56.092368  Montevideo    NaN    NaN      NaN       NaN     Venta
# 2 -58.257499  Entre Ríos    NaN    NaN      NaN       NaN     Venta
# 3 -54.808453   Maldonado    NaN    NaN      NaN       NaN     Venta
#
#   property_type  property_rooms  property_bedrooms  property_surface_total  \
# 0          Casa             6.0                NaN                     NaN
# 1          Casa             4.0                3.0                   193.0
# 2          Casa             NaN                NaN                   110.0
# 3          Casa             NaN                3.0                     NaN
#
#    property_surface_covered  property_price property_currency  \
# 0                     206.0             NaN               NaN
# 1                     193.0        390000.0               USD
# 2                      45.0         47000.0               USD
# 3                     180.0        400000.0               USD
#
#      property_title
# 0    Casa - Capital
# 1     Casa - Malvín
# 2    Casa - Uruguay
# 3  Casa - El Chorro

# %% [markdown]
# Se realiza un análisis introductorio incluyendo el tamaño del dataset y los tipos de dato de cada columna.

# %%
ds_properati.shape
# Out:
# (460154, 20)

# %%
ds_properati.dtypes
# Out:
# id                           object
# start_date                   object
# end_date                     object
# created_on                   object
# latitud                     float64
# longitud                    float64
# provincia                    object
# ciudad                       object
# barrio                       object
# place_l5                     object
# place_l6                    float64
# operation                    object
# property_type                object
# property_rooms              float64
# property_bedrooms           float64
# property_surface_total      float64
# property_surface_covered    float64
# property_price              float64
# property_currency            object
# property_title               object
# dtype: object

# %% [markdown]
# Seleccionamos los datos que se van a utilizar:
# únicamente los anuncios de propiedades de tipo vivienda ( Casa, PH y Departamento ) ubicados
# en Capital Federal cuyo tipo de operación sea venta y su precio se encuentre en dólares (USD). Por lo tanto, analizamos qué datos tenemos en cada una de esas variables.

# %%
ds_properati.operation.unique().tolist()
# Out:
# ['Venta', 'Alquiler', 'Alquiler temporal']

# %% [markdown]
# Vemos que las operaciones no son sólo Venta, por lo que eliminamos las filas que contengan Alquiler y Alquiler temporal ya que no nos interesan en este trabajo.

# %%
ds_properati.operation.isna().sum()
# Out:
# 0

# %% [markdown]
# Como no hay nans eliminamos todo lo que no sea Venta directamente.

# %%
ds_properati = ds_properati.drop(ds_properati.index[(ds_properati["operation"] != "Venta")])

# %% [markdown]
# Como se puede apreciar, ahora solo quedan entradas de propiedades en venta:

# %%
ds_properati.operation.unique().tolist()
# Out:
# ['Venta']

# %% [markdown]
# Ahora las filas que contengan datos diferentes a Casa, PH o Departamento.

# %%
ds_properati.property_type.isna().sum()
# Out:
# 0

# %% [markdown]
# Como no hay nans eliminamos todo lo que no sea Casa, Departamento, PH directamente.

# %%
ds_properati = ds_properati.drop(ds_properati.index[~ds_properati.property_type.isin(["Casa","Departamento","PH"])])

# %% [markdown]
# Y por ultimo, eliminamos las filas que contengan un Tipo de cambio diferente a USD

# %%
ds_properati.property_currency.isna().sum()
# Out:
# 10476

# %% [markdown]
# Tenemos 10476 NaNs, como serán tratados más adelante no se eliminan por el momento.

# %%
ds_properati = ds_properati.drop(ds_properati.index[~ds_properati.property_currency.isin(["USD",np.nan])])

# %% [markdown]
# Por ultimo, eliminamos las filas de las propiedades que no sean de Capital Federal.

# %%
ds_properati.provincia.isna().sum()
# Out:
# 0

# %% [markdown]
# Como no tenemos NaNs eliminamos todo lo que no sea Capital Federal.

# %%
ds_properati = ds_properati.drop(ds_properati.index[ds_properati["provincia"] != "Capital Federal"])

# %% [markdown]
# Podemos ver que todas las columnas elegidas quedan con los valores deseados.

# %%
display(ds_properati.operation.unique().tolist())
display(ds_properati.property_type.unique().tolist())
display(ds_properati.property_currency.unique().tolist())
display(ds_properati.provincia.unique().tolist())
# Out:
# ['Venta']
# ['Casa', 'Departamento', 'PH']
# ['USD', nan]
# ['Capital Federal']

# %%
ds_properati.shape
# Out:
# (95495, 20)

# %% [markdown]
# Vemos que redujimos el tamaño del DataSet ampliamente.

# %% [markdown]
# #### Variables Cuantitativas
# Estas pueden ser:
# - Cuantitativas discretas: Estas variables toman valores numéricos siendo que entre dos valores consecutivos de las mismas no existen valores intermedios. Pueden tomar un conjunto a lo sumo numerable de valores, vinculándose generalmente al proceso de contar.
# - Cuantitativas continuas: Estas variables también toman valores numéricos, pero entre dos valores de la variable existen infinitos valores intermedios, asociándose generalmente al proceso de medir.
#
# En el caso de nuestro data set las variables cuantitativas, como ya se indicó mas arriba, son:
# latitud, longitud, property_surface_total, property_surface_covered, price. Para trabajar sólo sobre estas se crea un nuevo data frame y se calculan medidas de resumen: media, mediana, q1, q3, moda.

# %%
df_cuantitativas = ds_properati[["latitud", "longitud", "property_surface_total", "property_surface_covered", "property_price", "property_bedrooms", "property_rooms"]]
dic_cuanti = []
for i in df_cuantitativas.columns:
  dic_cuanti.append({'variable': i, 'media': df_cuantitativas[i].mean(), 
                                    'moda': df_cuantitativas[i].mode().to_list(),
                                    'mediana': df_cuantitativas[i].median(),
                                    'rango': df_cuantitativas[i].max() - df_cuantitativas[i].min(),
                                    'primer cuartil': df_cuantitativas[i].quantile(0.25),
                                    'tercer cuartil': df_cuantitativas[i].quantile(0.75)})

pd.DataFrame(dic_cuanti)
# Out:
#                    variable          media           moda        mediana  \
# 0                   latitud     -34.591493  [-34.5412501]     -34.595745
# 1                  longitud     -58.450475  [-58.4729664]     -58.438983
# 2    property_surface_total     110.879165         [50.0]      65.000000
# 3  property_surface_covered      89.588025         [40.0]      58.000000
# 4            property_price  226101.465326     [110000.0]  143000.000000
# 5         property_bedrooms       2.020546          [1.0]       2.000000
# 6            property_rooms       2.829170          [3.0]       3.000000
#
#           rango  primer cuartil  tercer cuartil
# 0  2.956880e+01      -34.615920      -34.577395
# 1  1.733786e+01      -58.466523      -58.408848
# 2  1.369900e+05       45.000000      105.000000
# 3  2.169990e+05       40.000000       89.000000
# 4  2.140000e+07    95000.000000   237000.000000
# 5  7.100000e+01        1.000000        3.000000
# 6  3.900000e+01        2.000000        4.000000

# %% [markdown]
# A continuación se muestran gráficos de las distribuciones de estas variables cuantitativas. Los resultados observados pueden estar afectados por los valores faltantes que más adelante se tratarán.

# %%
plt.title('Distribución de la variable latitud')
plt.hist(ds_properati['latitud'], bins = 25 , alpha = 0.5) 
plt.xlabel("latitud (grados)") 
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %%
plt.title('Distribución de la variable longitud')
plt.hist(ds_properati['longitud'], bins = 25 , alpha = 0.5) 
plt.xlabel("longitud (grados)") 
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %%
plt.title('Distribución de la variable property_surface_total')
plt.hist(ds_properati['property_surface_total'], bins = 25 , alpha = 0.5) 
plt.xlabel("property_surface_total (m²)")
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %%
plt.title('Distribución de la variable property_surface_covered')
plt.hist(ds_properati['property_surface_covered'], bins = 25 , alpha = 0.5) 
plt.xlabel("property_surface_covered (m²)") 
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %% [markdown]
# Hasta acá notamos una distribución uniforme de estas variables.

# %%
plt.title('Distribución de la variable property_price')
plt.hist(ds_properati['property_price'], bins = 25 , alpha = 0.5) 

scale_factor = 0.5
xmin, xmax = plt.xlim()
plt.xlim(xmin * scale_factor, xmax * scale_factor)

plt.xlabel("property_price (USD) . 1e7") 
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %%
plt.title('Distribución de la variable property_rooms')
plt.hist(ds_properati['property_rooms'], bins = 25 , alpha = 0.5) 

plt.xlabel("property_rooms") 
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %%
plt.title('Distribución de la variable property_bedrooms')
plt.hist(ds_properati['property_bedrooms'], bins = 25 , alpha = 0.5) 

plt.xlabel("property_bedrooms") 
plt.ylabel("frecuencia")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Variables Cualitativas
# Estas pueden ser:
#
# - Nominales: Se diferencian de las Ordinales ya que no necesariamente llevan un orden. Dentro de esta clasificacion podrían llegar a ser de texto o numéricas:
#     - Texto: Estas podrían ser, por ejemplo el color de ojos de una persona, o algo no necesariamente ordenable.
#     - Numéricas: Pueden ser por ejemplo ids, o numeros de telefono.
# - Ordinales: Una variable cualitativa ordinal podría ser aquella que tenga una escala establecida, con valores ordenados.
#     - Texto: Esta puede ser por ejemplo las medallas de un torneo (Oro,plata,bronce), que mantienen un orden siendo la mejor Oro y la peor la de Bronce.
#     - Numéricas.
#
# En el principio del tp ya definimos todos las variables cualitativas que encontramos.
# Ahora mostramos los valores posibles de cada variable cualitativa, exeptuando las que tienen solamente un valor.

# %%
df_cual_nominal = ds_properati[["property_type","ciudad","property_title"]]
dic_cual_nominal = []
for cual in df_cual_nominal.columns:
  dic_cual_nominal.append({"variable": cual, "tipos" : ds_properati[cual].unique().tolist()})
pd.DataFrame(dic_cual_nominal)
# Out:
#          variable                                              tipos
# 0   property_type                           [Casa, Departamento, PH]
# 1          ciudad  [nan, Boca, Once, Boedo, Flores, Nuñez, Retiro...
# 2  property_title  [VENTA CASA LLAVE EN MANO - COSTA ESMERALDA , ...

# %% [markdown]
# Calculamos la frecuencia de cada categoria segun los valores tomados.

# %% [markdown]
# Para cada categoria tenemos:

# %%
ds_agrupado_PT = ds_properati["property_type"].value_counts()
ds_agrupado_PL_3 = ds_properati["ciudad"].value_counts()
ds_agrupado_CO = ds_properati["created_on"].value_counts()

# %% [markdown]
# Con sus respectivas tablas con la frecuencia:

# %%
display(ds_agrupado_PT)
# Out:
# Departamento    81871
# PH               9332
# Casa             4292
# Name: property_type, dtype: int64

# %% [markdown]
# Para ciudad:

# %%
display(ds_agrupado_PL_3)
# Out:
# Palermo                 14534
# Belgrano                 9038
# Caballito                7238
# Recoleta                 6412
# Villa Urquiza            4749
# Almagro                  4119
# Nuñez                    3587
# Villa Crespo             3206
# Flores                   3153
# Barrio Norte             3007
# Balvanera                2572
# Villa Devoto             1964
# Colegiales               1964
# Villa del Parque         1842
# Saavedra                 1838
# Puerto Madero            1542
# San Telmo                1396
# San Cristobal            1311
# San Nicolás              1304
# Retiro                   1275
# Barracas                 1261
# Boedo                    1252
# Floresta                 1211
# Monserrat                1123
# Parque Chacabuco         1085
# Villa Pueyrredón         1018
# Coghlan                   993
# Villa Luro                747
# Mataderos                 726
# Chacarita                 704
# Liniers                   675
# Villa Ortuzar             665
# Parque Patricios          645
# Villa Lugano              617
# Paternal                  570
# Congreso                  544
# Monte Castro              505
# Constitución              453
# Villa General Mitre       444
# Villa Santa Rita          441
# Once                      418
# Parque Chas               384
# Parque Avellaneda         383
# Boca                      365
# Versalles                 319
# Velez Sarsfield           244
# Agronomía                 236
# Abasto                    233
# Pompeya                   219
# Villa Real                143
# Tribunales                116
# Parque Centenario          93
# Centro / Microcentro       77
# Villa Soldati              45
# Villa Riachuelo            35
# Las Cañitas                13
# Catalinas                   7
# Name: ciudad, dtype: int64

# %% [markdown]
# Por fecha de creación:

# %%
display(ds_agrupado_CO)
# Out:
# 2021-12-16    4697
# 2021-02-13    2129
# 2021-11-03    1021
# 2021-08-03     839
# 2021-04-10     827
#               ...
# 2021-12-26      18
# 2021-12-19      13
# 2021-01-02      12
# 2021-10-24      10
# 2021-11-27       1
# Name: created_on, Length: 365, dtype: int64

# %% [markdown]
# ##### Conclusiones

# %% [markdown]
# Se puede observar que para la categoría de ciudad la zona más frecuente de venta de propiedades es en Palermo, además de esto se puede ver que el tipo de propiedad más frecuente en venta es el de Departamento. Para el caso de los ambientes, se puede ver que el más frecuente son 3 y para las habitaciones es 1. No le vemos mucho sentido mostrar todos los tipos de "property title" ya que no hay valores frecuentes. También se ve que para la categoría de bedrooms, el valor más frecuente es 1. Por último, se puede ver que se crearon publicaciones todos los días del año siendo el más frecuente el 16 de Diciembre con 17417 publicaciones.
#  Se podría hacer un gráfico con los resultados más frecuentes (para mejor visualización). Si hay muchos tipos lo truncamos en los 10 valores más frecuentes para poder ver mejor.

# %%
ds_agrupado_PL_3[:10].plot(kind = "barh", title="Frecuencia de valores de la variable ciudad", xlabel="frecuencia",ylabel="zona")
# Out:
# <AxesSubplot: title={'center': 'Frecuencia de valores de la variable ciudad'}, xlabel='frecuencia', ylabel='zona'>

# %%
ds_agrupado_PT.plot(kind = "barh", title="Frecuencia de valores de la variable Property Title", xlabel="frecuencia",ylabel="Tipo de Venta")
# Out:
# <AxesSubplot: title={'center': 'Frecuencia de valores de la variable Property Title'}, xlabel='frecuencia', ylabel='Tipo de Venta'>

# %%
(ds_properati["property_rooms"])[:10].plot(kind = "barh", title="Frecuencia de valores de la variable Property Rooms", xlabel="frecuencia",ylabel="Cantidad de ambientes")
# Out:
# <AxesSubplot: title={'center': 'Frecuencia de valores de la variable Property Rooms'}, xlabel='frecuencia', ylabel='Cantidad de ambientes'>

# %%
ds_agrupado_CO[:10].plot(kind = "barh", title="Frecuencia de valores de la variable created_on", xlabel="frecuencia",ylabel="Fecha de Publicacion")
# Out:
# <AxesSubplot: title={'center': 'Frecuencia de valores de la variable created_on'}, xlabel='frecuencia', ylabel='Fecha de Publicacion'>

# %%
(ds_properati["property_bedrooms"])[:10].plot(kind = "barh", title="Frecuencia de valores de la variable property_bedrooms", xlabel="frecuencia",ylabel="cant de habitaciones")
# Out:
# <AxesSubplot: title={'center': 'Frecuencia de valores de la variable property_bedrooms'}, xlabel='frecuencia', ylabel='cant de habitaciones'>

# %% [markdown]
# #### Variables irrelevantes en el análisis

# %% [markdown]
# Se descartan las columnas de **id** (que no son de utilidad para el análisis ya que no aportan información alguna sobre las propiedades), **property_title** (porque solamente es una forma que tiene el vendedor de identificar su anuncio, que suele contener la información que ya figura en las otras variables). También sacamos la fecha de inicio (porque es igual a la fecha de creación) y de fin de la publicación.

# %%
ds_properati.drop(["id", "property_title","start_date","end_date"], axis=1, inplace=True)
ds_properati.reset_index(drop=True,inplace=True)
ds_properati.head()
# Out:
#    created_on    latitud   longitud        provincia ciudad barrio place_l5  \
# 0  2021-09-09        NaN        NaN  Capital Federal    NaN    NaN      NaN
# 1  2021-09-09 -34.637319 -58.361124  Capital Federal   Boca    NaN      NaN
# 2  2021-09-09 -34.628647 -58.361871  Capital Federal   Boca    NaN      NaN
# 3  2021-09-09 -34.599506 -58.404138  Capital Federal   Once    NaN      NaN
# 4  2021-09-09 -34.610027 -58.401934  Capital Federal   Once    NaN      NaN
#
#    place_l6 operation property_type  property_rooms  property_bedrooms  \
# 0       NaN     Venta          Casa             4.0                3.0
# 1       NaN     Venta  Departamento             3.0                2.0
# 2       NaN     Venta  Departamento             4.0                3.0
# 3       NaN     Venta  Departamento             2.0                1.0
# 4       NaN     Venta  Departamento             4.0                2.0
#
#    property_surface_total  property_surface_covered  property_price  \
# 0                   171.0                     133.0        210000.0
# 1                    58.0                      55.0         82900.0
# 2                    70.0                      70.0         99000.0
# 3                    43.0                      43.0             NaN
# 4                     NaN                     104.0        146000.0
#
#   property_currency
# 0               USD
# 1               USD
# 2               USD
# 3               NaN
# 4               USD

# %% [markdown]
# #### Covarianza y Correlación
#
# Tanto la covarianza como la correlación son medidas de asociación lineal entre dos variables.
# La Covarianza indica la dirección/sentido de esa asociación lineal y la Correlación mide tanto la fuerza como el sentido de dicha asociación lineal.
#
# El valor (magnitud) de la covarianza depende las unidades en que se miden las variables.
# Si las escalas de medida de las variables fueran muy diferentes, la variabilidad estaría dominada por las variables con mayores magnitudes.
#
# La Correlación se define como la covarianza de los datos estandarizados, por lo que evita el problema de las diferencias en las escalas de medición. Se obtiene dividiendo la covarianza de dos variables por el producto de sus desvíos estándar.
#
# Los valores del coeficiente de correlación van de -1 a 1. Cuanto más cerca esté de 1 (lineal perfecta positiva) o -1 (lineal perfecta negativa), más estrechamente relacionadas estarán las dos variables. El signo positivo significa la dirección de la correlación, es decir, si una de las variables aumenta, se supone que la otra también aumentará. Al contar con una muestra poblacional se calcula la correlación mediante un estimador muestral que es el de Pearson.

# %%
matriz_cov = ds_properati.cov(numeric_only=True)
matriz_cov
# Out:
#                              latitud     longitud  place_l6  property_rooms  \
# latitud                     0.034332    -0.011279       NaN        0.001365
# longitud                   -0.011279     0.091288       NaN       -0.003179
# place_l6                         NaN          NaN       NaN             NaN
# property_rooms              0.001365    -0.003179       NaN        2.062727
# property_bedrooms           0.000523    -0.003094       NaN        1.329521
# property_surface_total      4.525238    -4.400231       NaN       97.239380
# property_surface_covered    0.431587    -0.334969       NaN       78.266839
# property_price            946.889376  2131.540439       NaN   213737.102742
#
#                           property_bedrooms  property_surface_total  \
# latitud                            0.000523            4.525238e+00
# longitud                          -0.003094           -4.400231e+00
# place_l6                                NaN                     NaN
# property_rooms                     1.329521            9.723938e+01
# property_bedrooms                  1.296921            7.848508e+01
# property_surface_total            78.485076            1.056879e+06
# property_surface_covered          59.238184            5.212981e+05
# property_price                155004.136618            2.666578e+07
#
#                           property_surface_covered  property_price
# latitud                               4.315872e-01    9.468894e+02
# longitud                             -3.349688e-01    2.131540e+03
# place_l6                                       NaN             NaN
# property_rooms                        7.826684e+01    2.137371e+05
# property_bedrooms                     5.923818e+01    1.550041e+05
# property_surface_total                5.212981e+05    2.666578e+07
# property_surface_covered              1.060903e+06    1.775952e+07
# property_price                        1.775952e+07    1.014777e+11

# %%
matriz_corr=ds_properati.corr(numeric_only=True)
matriz_corr
# Out:
#                            latitud  longitud  place_l6  property_rooms  \
# latitud                   1.000000 -0.201465       NaN        0.005630
# longitud                 -0.201465  1.000000       NaN       -0.007978
# place_l6                       NaN       NaN       NaN             NaN
# property_rooms            0.005630 -0.007978       NaN        1.000000
# property_bedrooms         0.002447 -0.008844       NaN        0.872374
# property_surface_total    0.023936 -0.014265       NaN        0.067207
# property_surface_covered  0.002182 -0.001037       NaN        0.073528
# property_price            0.016657  0.023285       NaN        0.488424
#
#                           property_bedrooms  property_surface_total  \
# latitud                            0.002447                0.023936
# longitud                          -0.008844               -0.014265
# place_l6                                NaN                     NaN
# property_rooms                     0.872374                0.067207
# property_bedrooms                  1.000000                0.067833
# property_surface_total             0.067833                1.000000
# property_surface_covered           0.071800                0.652844
# property_price                     0.425040                0.085217
#
#                           property_surface_covered  property_price
# latitud                                   0.002182        0.016657
# longitud                                 -0.001037        0.023285
# place_l6                                       NaN             NaN
# property_rooms                            0.073528        0.488424
# property_bedrooms                         0.071800        0.425040
# property_surface_total                    0.652844        0.085217
# property_surface_covered                  1.000000        0.056226
# property_price                            0.056226        1.000000

# %% [markdown]
# A continuación se muestra la matriz de correlación en un Heatmap:

# %%
plt.figure(figsize = (15,8))
sns.heatmap(matriz_corr, annot = True, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Se orbserva una la "cruz" blanca correspondiente a los valores NaN (100%) de la columna *place_l6*.
# Por otro lado, siguiendo la escala de colores aquellas celdas más cercanas al rojo presentan una buena correlación lineal positiva (lineal creciente). En este caso no se observan correlaciones cercanas a -1, que también implicarían relación linealidad pero decreciente.
#
# Teniendo esto en cuenta, vemos que las variables que mejor se relacionan linealmente son: (Ignoramos la diagonal, dado que es la correlación de la variable consigo misma que siempre es perfecta)
# - *property_bedrooms* con *property_rooms*  ($\rho$ = 0.87)
# - *property_surface_total* con *property_surface_covered*  ($\rho$ = 0.65)

# %%
#sns.pairplot(ds_properati, height=2)

# %% [markdown]
# En este pairplot podemos ver las distribuciones bivariadas. En especial nos sirve para efectivamente ver que *property_surface_total* con *property_surface_covered*  y *property_bedrooms* con *property_rooms* tienen una bastante tendencia lineal tal como exponía su correlación de pearson.

# %% [markdown]
# #### Datos Faltantes

# %% [markdown]
# ##### Columnas

# %% [markdown]
# Para todas las columnas se realiza la cuenta del porcentaje de los datos faltantes

# %%
porcentajes = ds_properati.isna().sum() / len(ds_properati) * 100
porcentajes
# Out:
# created_on                    0.000000
# latitud                       3.970889
# longitud                      3.970889
# provincia                     0.000000
# ciudad                        0.455521
# barrio                       96.099272
# place_l5                    100.000000
# place_l6                    100.000000
# operation                     0.000000
# property_type                 0.000000
# property_rooms                1.148751
# property_bedrooms            11.672862
# property_surface_total        5.218074
# property_surface_covered      3.598094
# property_price                1.245091
# property_currency             1.304780
# dtype: float64

# %%
ds_properati["barrio"].value_counts()
# Out:
# Palermo Hollywood    1585
# Palermo Chico        1147
# Palermo Soho          821
# Palermo Viejo         172
# Name: barrio, dtype: int64

# %% [markdown]
# Se puede notar que las columnas con mayor datos faltantes son las de place_l6, place_l5 y barrio, siendo los primeros 2 un 100% de datos faltantes y barrio teniendo un 95% de datos faltantes, siendo Palermo Hollywood el dato no nulo mas frecuente.

# %% [markdown]
# Realizamos un gráfico a partir de los nans de las variables con respecto al total del dataset.

# %%
porcentajes.plot(kind = "barh", title="Porcentaje de datos nulos respecto del total del dataset", xlabel="Porcentaje",ylabel="Variable")
plt.show()

# %% [markdown]
# ##### Filas

# %% [markdown]
# Por otro lado, calculamos el porcentaje de datos faltantes por cada registro sobre el total de datos del registro.

# %%
porcentaje_Nan_fila = (ds_properati.isnull().sum(axis=1) / ds_properati.columns.size * 100).sort_values(ascending=False).value_counts()
porcentaje_Nan_fila
# Out:
# 18.75    71160
# 25.00    15743
# 31.25     4901
# 12.50     2421
# 37.50      962
# 43.75      173
# 50.00      126
# 62.50        4
# 56.25        4
# 68.75        1
# dtype: int64

# %% [markdown]
# Lo que se muestra arriba corresponde al porcentaje de nans a la izquierda y a la derecha la cantidad de filas que tienen ese porcentaje.

# %%
(ds_properati.isnull().sum(axis=1)).sort_values(ascending=False).value_counts()
# Out:
# 3     71160
# 4     15743
# 5      4901
# 2      2421
# 6       962
# 7       173
# 8       126
# 10        4
# 9         4
# 11        1
# dtype: int64

# %% [markdown]
# Se puede ver que hay 1 registro con 11 valores faltantes, 4 con 10 y 4 con 9 siendo estos los registros con más valores faltantes (se muestran a continuación). También se puede analizar que 71160 registros tienen 3 valores faltantes, por lo que se puede concluir que es mucho más frecuente tener 3 registros faltantes.

# %%
ds_properati[(ds_properati.isnull().sum(axis=1) == 11) | (ds_properati.isnull().sum(axis=1) == 10) | (ds_properati.isnull().sum(axis=1) == 9)]
# Out:
#        created_on  latitud  longitud        provincia    ciudad  \
# 8224   2021-07-19      NaN       NaN  Capital Federal  Congreso
# 10269  2021-06-23      NaN       NaN  Capital Federal       NaN
# 15093  2021-10-18      NaN       NaN  Capital Federal       NaN
# 22732  2021-07-16      NaN       NaN  Capital Federal   Palermo
# 25212  2021-03-25      NaN       NaN  Capital Federal       NaN
# 25213  2021-03-25      NaN       NaN  Capital Federal       NaN
# 25351  2021-05-13      NaN       NaN  Capital Federal     Nuñez
# 33110  2021-05-26      NaN       NaN  Capital Federal       NaN
# 63230  2021-03-04      NaN       NaN  Capital Federal   Almagro
#
#                   barrio place_l5  place_l6 operation property_type  \
# 8224                 NaN      NaN       NaN     Venta            PH
# 10269                NaN      NaN       NaN     Venta  Departamento
# 15093                NaN      NaN       NaN     Venta  Departamento
# 22732  Palermo Hollywood      NaN       NaN     Venta  Departamento
# 25212                NaN      NaN       NaN     Venta  Departamento
# 25213                NaN      NaN       NaN     Venta  Departamento
# 25351                NaN      NaN       NaN     Venta            PH
# 33110                NaN      NaN       NaN     Venta  Departamento
# 63230                NaN      NaN       NaN     Venta  Departamento
#
#        property_rooms  property_bedrooms  property_surface_total  \
# 8224              NaN               10.0                     NaN
# 10269             NaN                NaN                    26.0
# 15093             NaN                NaN                    26.0
# 22732             NaN                NaN                     NaN
# 25212             1.0                NaN                     NaN
# 25213             1.0                NaN                     NaN
# 25351             NaN                NaN                   174.0
# 33110             2.0                NaN                     NaN
# 63230             NaN                NaN                    38.0
#
#        property_surface_covered  property_price property_currency
# 8224                      428.0             NaN               NaN
# 10269                       NaN             NaN               NaN
# 15093                       NaN         85000.0               USD
# 22732                     128.0             NaN               NaN
# 25212                      31.0             NaN               NaN
# 25213                      40.0             NaN               NaN
# 25351                     105.0             NaN               NaN
# 33110                      43.0             NaN               NaN
# 63230                       NaN             NaN               NaN

# %% [markdown]
# Se pueden graficar estos porcentajes para obtener una mejor visualizacion de los datos

# %%
porcentaje_Nan_fila.plot(kind = "barh", title="Porcentaje de datos nulos respecto del total del dataset", xlabel="Cantidad de registros",ylabel="Porcentaje")
plt.show()

# %% [markdown]
# A partir de este grafico se puede concluir que aproximadamente 71 mil registros tienen 18.8% de datos faltantes, siendo este el porcentaje mas frecuente de datos faltantes en un registro.

# %% [markdown]
# ##### Estrategias para aplicar en los datos faltantes

# %% [markdown]
# Opción 1: Eliminar registros o variables
# Para un primer enfoque, si el porcentaje de una columna frente a los datos faltantes es muy grande, se podría borrar la columna entera, ya que al tener en su mayoría valores faltantes, estos no aportan valor al dataset.
#
# Esta estrategia es particularmente útil en aquellos casos en los que los datos faltantes sean MCAR (missing completly at random), ya que en estos casos se tiene la certeza de que no es posible recuperar los datos faltantes bajo algún criterio. En otro caso, la eliminación de una columna puede generar pórdidas de información, por lo que es una estrategia que debe usarse con precaución.

# %% [markdown]
# Opción 2: Crear otra Categoría
# Por otro lado, se podría de tomar los datos faltantes de la columna como una categoría más, incluyendo una descripción breve de qué significan los datos faltantes. Por ejemplo en nuestro dataset, dentro de la columna "property rooms", al tener un 1% de datos faltantes, se podría considerar una nueva categoría "ambientes no reportados" incluyendo a estos.

# %% [markdown]
# Opción 3: Imputaciones
#
# Otra estrategia es la de la imputación, que comprende un subconjunto de estrategias que permiten reemplazar los datos faltantes por datos con información significativa bajo algún criterio. Cual de estas estrategias usar depende de las necesidades del problema, o de los recursos de los que se disponga.
#
# Como ya se mencionó, la opción 3 es una agrupación de un conjunto de estrategias para resolver un mismo problema, el de imputar información, se describen algunas de ellas:
#
# **1-Sustitución de datos:** Es un simple reemplazo de valores no observados. Se basa en la consulta a expertos en los datos analizados.
#
# **2-Sustitución por media o mediana:** Entre el conjunto de datos analizado, se toma el promedio de ellos, y se reemplazan los datos faltantes por el mismo (no conviene hacerlo cuando gran mayoría de los datos son faltantes o nulos).
#
# **3-Imputación Cold Deck** Selecciona valores de fuentes distintas a la base de datos analizada, esto es, se busca información oficial que permita rellenar los datos faltantes.
#
# **4-Imputacion Hot Deck:** Reemplaza valores faltantes con valores similares entre si (un ejemplo de esto, es tener que rellenar cuantos baños tiene un apartamento de 3 ambientes tomando como referencia datos de otros departamentos de 3 ambientes dentro del dataset).
#
# **5-Imputación por regresión:** Se predice el dato faltante a través de un modelo de regresión.
#
# **6-MICE (multivariate imputation by chained equations):** Se usa basandose de que el origen de los datos faltantes es missing at random (MAR). Este proceso de imputación es un proceso iterativo, en cada iteración cada valor faltante se produce en función de las variables restantes. Cuántas iteraciones hacer depende del problema a resolver.

# %% [markdown]
# Para las columnas de place_l5 y place_l6 decidimos usar la opción 1 ya que la gran mayoría de valores son datos faltantes, por lo que no tendría sentido tomar una media de sus valores. Además no sabemos qué representan porque no se provee información de estas variables en la fuente de la que proviene el set de datos.

# %%
columnas_a_eliminar = ["place_l5","place_l6"]
ds_properati.drop(columnas_a_eliminar, axis='columns', inplace=True)

# %% [markdown]
# ##### Análisis de valores faltantes en *barrio*

# %% [markdown]
# Analizamos qué hacer con *barrio*. En primer lugar listamos los valores de *ciudad* y *barrio* para ver qué representan.

# %%
ds_properati["ciudad"].unique()
# Out:
# array([nan, 'Boca', 'Once', 'Boedo', 'Flores', 'Nuñez', 'Retiro',
#        'Almagro', 'Coghlan', 'Liniers', 'Palermo', 'Pompeya', 'Barracas',
#        'Belgrano', 'Floresta', 'Recoleta', 'Saavedra', 'Balvanera',
#        'Caballito', 'Chacarita', 'Mataderos', 'Monserrat', 'San Telmo',
#        'Versalles', 'Agronomía', 'Colegiales', 'Tribunales', 'Villa Luro',
#        'Parque Chas', 'Barrio Norte', 'Monte Castro', 'San Nicolás',
#        'Villa Crespo', 'Villa Devoto', 'Villa Lugano', 'Constitución',
#        'Puerto Madero', 'San Cristobal', 'Villa Ortuzar', 'Villa Urquiza',
#        'Velez Sarsfield', 'Parque Chacabuco', 'Parque Patricios',
#        'Villa Santa Rita', 'Villa del Parque', 'Parque Avellaneda',
#        'Villa Pueyrredón', 'Villa General Mitre', 'Centro / Microcentro',
#        'Villa Real', 'Congreso', 'Paternal', 'Abasto', 'Villa Riachuelo',
#        'Parque Centenario', 'Villa Soldati', 'Las Cañitas', 'Catalinas'],
#       dtype=object)

# %%
ds_properati["barrio"].unique()
# Out:
# array([nan, 'Palermo Chico', 'Palermo Soho', 'Palermo Viejo',
#        'Palermo Hollywood'], dtype=object)

# %% [markdown]
# Aquí se puede observar que en el caso de Capital Federal *ciudad* hace referencia al barrio y que los valores de *barrio* no son relevantes frente a los otros. Por lo tanto, dada la alta cantidad de NaNs se procede a eliminar la columna.

# %%
ds_properati.drop("barrio", axis=1, inplace=True)
ds_properati = ds_properati.rename(columns={'ciudad':'barrio'})
ds_properati.head(3)
# Out:
#    created_on    latitud   longitud        provincia barrio operation  \
# 0  2021-09-09        NaN        NaN  Capital Federal    NaN     Venta
# 1  2021-09-09 -34.637319 -58.361124  Capital Federal   Boca     Venta
# 2  2021-09-09 -34.628647 -58.361871  Capital Federal   Boca     Venta
#
#   property_type  property_rooms  property_bedrooms  property_surface_total  \
# 0          Casa             4.0                3.0                   171.0
# 1  Departamento             3.0                2.0                    58.0
# 2  Departamento             4.0                3.0                    70.0
#
#    property_surface_covered  property_price property_currency
# 0                     133.0        210000.0               USD
# 1                      55.0         82900.0               USD
# 2                      70.0         99000.0               USD

# %% [markdown]
# Dado que contamos con las latitudes y longitudes de la ubicación de las observaciones, vamos a imputar los datos faltantes de *ciudad* usándolos si no son nulos. Para eso utilizaremos Geopandas y los polígonos de barrios de CABA provistos por la página del gobierno de la ciudad. Se estaría realizando una imputación Cold Deck.

# %%
ds_properati['barrio'].isnull().sum()
# Out:
# 435

# %% [markdown]
# Tenemos 435 filas con *ciudad* NaN.

# %%
ds_properati.reset_index(drop=True, inplace=True) #acomodamos el ds

# %%
# !pip install geopandas
import geopandas as gp
# Out:
# Requirement already satisfied: geopandas in /home/tomas/anaconda3/lib/python3.8/site-packages (0.11.1)
# Requirement already satisfied: shapely<2,>=1.7 in /home/tomas/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.4)
# Requirement already satisfied: packaging in /home/tomas/.local/lib/python3.8/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from geopandas) (3.4.0)
# Requirement already satisfied: fiona>=1.8 in /home/tomas/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pandas>=1.0.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from geopandas) (1.5.0)
# Requirement already satisfied: attrs>=17 in /home/tomas/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: munch in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: setuptools in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (49.2.0.post20200714)
# Requirement already satisfied: cligj>=0.5 in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click>=4.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: certifi in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.6.20)
# Requirement already satisfied: click-plugins>=1.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/tomas/anaconda3/lib/python3.8/site-packages (from pandas>=1.0.0->geopandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/tomas/.local/lib/python3.8/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tomas/anaconda3/lib/python3.8/site-packages (from pandas>=1.0.0->geopandas) (2020.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/tomas/anaconda3/lib/python3.8/site-packages (from packaging->geopandas) (2.4.7)

# %%
poligonos = gp.read_file("barrios.geojson")
poligonos.head()
# Out:
#              BARRIO  COMUNA    PERIMETRO          AREA  OBJETO  \
# 0         CHACARITA    15.0  7724.852955  3.115707e+06  BARRIO
# 1          PATERNAL    15.0  7087.513295  2.229829e+06  BARRIO
# 2      VILLA CRESPO    15.0  8131.857075  3.615978e+06  BARRIO
# 3  VILLA DEL PARQUE    11.0  7705.389797  3.399596e+06  BARRIO
# 4           ALMAGRO     5.0  8537.901368  4.050752e+06  BARRIO
#
#                                             geometry
# 0  MULTIPOLYGON (((-58.45282 -34.59599, -58.45366...
# 1  MULTIPOLYGON (((-58.46558 -34.59656, -58.46562...
# 2  MULTIPOLYGON (((-58.42375 -34.59783, -58.42495...
# 3  MULTIPOLYGON (((-58.49461 -34.61487, -58.49479...
# 4  MULTIPOLYGON (((-58.41287 -34.61412, -58.41282...

# %% [markdown]
# Graficamos los polígonos.

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.set_title('Barrios de CABA')

ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
poligonos.plot(ax=ax,column='BARRIO')
# Out:
# <AxesSubplot: title={'center': 'Barrios de CABA'}, xlabel='Longitud', ylabel='Latitud'>

# %% [markdown]
# Se descartan las coordenadas NaNs ya que no son el objetivo de esta ocasión y creamos otro data frame que contenga las filas con ciudades NaN.

# %%
ds_copia = ds_properati.copy()

ds_barrio_nan = ds_copia.loc[(ds_copia["barrio"].isna()) & (ds_copia["latitud"].isna()==False) & (ds_copia["longitud"].isna()==False)]
ds_barrio_nan.head(3)
# Out:
#       created_on    latitud   longitud        provincia barrio operation  \
# 602   2021-02-20 -31.678900 -63.879640  Capital Federal    NaN     Venta
# 1277  2021-02-09 -34.581285 -58.469703  Capital Federal    NaN     Venta
# 1355  2021-02-09 -34.606577 -58.449072  Capital Federal    NaN     Venta
#
#      property_type  property_rooms  property_bedrooms  property_surface_total  \
# 602           Casa             5.0                4.0                   220.0
# 1277            PH             3.0                NaN                   198.0
# 1355  Departamento             2.0                NaN                    52.0
#
#       property_surface_covered  property_price property_currency
# 602                      220.0        230000.0               USD
# 1277                      94.0        268000.0               USD
# 1355                      50.0        127000.0               USD

# %%
display(ds_barrio_nan.barrio.unique())
display(ds_barrio_nan.barrio.isna().sum())
# Out:
# array([nan], dtype=object)
# 260

# %% [markdown]
# Todos los barrios (260) son NaN

# %% [markdown]
# Creamos una geometría de punto para el par longitud y latitud.

# %%
points = gp.GeoDataFrame(ds_barrio_nan, geometry=gp.points_from_xy(ds_barrio_nan.longitud, ds_barrio_nan.latitud))
points.head(3)
# Out:
#       created_on    latitud   longitud        provincia barrio operation  \
# 602   2021-02-20 -31.678900 -63.879640  Capital Federal    NaN     Venta
# 1277  2021-02-09 -34.581285 -58.469703  Capital Federal    NaN     Venta
# 1355  2021-02-09 -34.606577 -58.449072  Capital Federal    NaN     Venta
#
#      property_type  property_rooms  property_bedrooms  property_surface_total  \
# 602           Casa             5.0                4.0                   220.0
# 1277            PH             3.0                NaN                   198.0
# 1355  Departamento             2.0                NaN                    52.0
#
#       property_surface_covered  property_price property_currency  \
# 602                      220.0        230000.0               USD
# 1277                      94.0        268000.0               USD
# 1355                      50.0        127000.0               USD
#
#                          geometry
# 602   POINT (-63.87964 -31.67890)
# 1277  POINT (-58.46970 -34.58129)
# 1355  POINT (-58.44907 -34.60658)

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')

poligonos.plot(ax=ax,column='BARRIO',alpha=0.5) #ver por q no se muestra
points.plot(ax=ax) 
plt.show()

# %%
for barrio in poligonos.BARRIO:
    b = poligonos[poligonos['BARRIO'] == barrio].index[0] #obtengo el indice del barrio en el df

    #creo un vector true/false si la propiedad está en el barrio (interseccion punto con poligono)
    mask = points.within(poligonos.loc[b, 'geometry']) 
    points.loc[mask,"barrio"] = barrio
points.head()
# Out:
#    created_on    latitud   longitud        provincia barrio operation  \
# 0  2021-09-09 -34.631621 -58.416825  Capital Federal  BOEDO     Venta
# 1  2021-09-09 -34.623886 -58.412746  Capital Federal  BOEDO     Venta
# 2  2021-09-09 -34.625588 -58.423056  Capital Federal  BOEDO     Venta
# 3  2021-09-09 -34.629398 -58.425852  Capital Federal  BOEDO     Venta
# 4  2021-09-09 -34.626595 -58.420019  Capital Federal  BOEDO     Venta
#
#   property_type  property_rooms  property_bedrooms  property_surface_total  \
# 0            PH             4.0                2.0              109.394701
# 1            PH             2.0                1.0               61.000000
# 2            PH             4.0                2.0              104.000000
# 3  Departamento             2.0                1.0               62.000000
# 4            PH             4.0                3.0              111.000000
#
#    property_surface_covered  property_price property_currency  \
# 0                      73.0        250000.0               USD
# 1                      46.0        100000.0               USD
# 2                      54.0        185000.0               USD
# 3                      44.0        100000.0               USD
# 4                     101.0        110000.0               USD
#
#                       geometry
# 0  POINT (-58.41683 -34.63162)
# 1  POINT (-58.41275 -34.62389)
# 2  POINT (-58.42306 -34.62559)
# 3  POINT (-58.42585 -34.62940)
# 4  POINT (-58.42002 -34.62660)

# %%
display(points.barrio.isna().sum())
display(points.barrio.unique())
# Out:
# 0
# array(['BOEDO', 'FLORES', 'SAAVEDRA', 'NUÑEZ', 'RETIRO', 'ALMAGRO',
#        'VILLA URQUIZA', 'COGHLAN', 'PALERMO', 'RECOLETA', 'VILLA CRESPO',
#        'BARRACAS', 'VILLA ORTUZAR', 'BELGRANO', 'VELEZ SARSFIELD',
#        'FLORESTA', 'BALVANERA', 'CABALLITO', 'CHACARITA', 'MONSERRAT',
#        'SAN TELMO', 'VERSALLES', 'AGRONOMIA', 'COLEGIALES', 'SAN NICOLAS',
#        'MONTE CASTRO', 'VILLA LURO', 'PARQUE CHAS', 'VILLA DEVOTO',
#        'CONSTITUCION', 'SAN CRISTOBAL', 'PARQUE CHACABUCO',
#        'VILLA SANTA RITA', 'VILLA DEL PARQUE', 'VILLA PUEYRREDON',
#        'VILLA GRAL. MITRE', 'VILLA REAL', 'BOCA', 'MATADEROS',
#        'PUERTO MADERO', 'LINIERS', 'PATERNAL', 'PARQUE PATRICIOS',
#        'VILLA LUGANO', 'PARQUE AVELLANEDA', 'VILLA RIACHUELO',
#        'VILLA SOLDATI', 'NUEVA POMPEYA'], dtype=object)

# %% [markdown]
# Vemos que 51 ciudades (260-209) encontraron coincidencia en algún polígono y se les imputó su barrio correspondiente.
# Finalmente volcamos los resultados en el data set original.

# %%
ds_barrio_nan.drop("geometry", axis=1)
ds_properati.loc[ds_barrio_nan.index] = ds_barrio_nan 
ds_properati
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/tomas/Escritorio/Facultad/Orga_De_Datos/TP1/7506R_TP1_GRUPO06_ENTREGA_N1.ipynb Celda 129 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/tomas/Escritorio/Facultad/Orga_De_Datos/TP1/7506R_TP1_GRUPO06_ENTREGA_N1.ipynb#Y242sZmlsZQ%3D%3D?line=0'>1</a> ds_barrio_nan.drop("geometry", axis=1)
# ----> <a href='vscode-notebook-cell:/home/tomas/Escritorio/Facultad/Orga_De_Datos/TP1/7506R_TP1_GRUPO06_ENTREGA_N1.ipynb#Y242sZmlsZQ%3D%3D?line=1'>2</a> ds_properati.loc[ds_barrio_nan.index] = ds_barrio_nan
#       <a href='vscode-notebook-cell:/home/tomas/Escritorio/Facultad/Orga_De_Datos/TP1/7506R_TP1_GRUPO06_ENTREGA_N1.ipynb#Y242sZmlsZQ%3D%3D?line=2'>3</a> ds_properati
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:815, in _LocationIndexer.__setitem__(self, key, value)
#     813 else:
#     814     key = com.apply_if_callable(key, self.obj)
# --> 815 indexer = self._get_setitem_indexer(key)
#     816 self._has_valid_setitem_indexer(key)
#     818 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:704, in _LocationIndexer._get_setitem_indexer(self, key)
#     700 if isinstance(key, range):
#     701     # GH#45479 test_loc_setitem_range_key
#     702     key = list(key)
# --> 704 return self._convert_to_indexer(key, axis=0)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1397, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1395         return key
#    1396     else:
# -> 1397         return self._get_listlike_indexer(key, axis)[1]
#    1398 else:
#    1399     try:
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1433, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1430 ax = self.obj._get_axis(axis)
#    1431 axis_name = self.obj._get_axis_name(axis)
# -> 1433 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1435 return keyarr, indexer
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[602, 1277, 1355, 1764, 1765, 1766, 2417, 2779, 4169, 4901, 4902, 4907, 6772, 6773, 6774, 6775, 6776, 6777, 6779, 6780, 6781, 6782, 6783, 6784, 6785, 6786, 6787, 6788, 6789, 8983, 9357, 9365, 9368, 10715, 11395, 11885, 11886, 11887, 12275, 12790, 13090, 13391, 14096, 14228, 17873, 19786, 19787, 19788, 19789, 19790, 21453, 21454, 21455, 21465, 21466, 21467, 21485, 21486, 21487, 21491, 21492, 21493, 22192, 22233, 22234, 22636, 23382, 23777, 27610, 27611, 27612, 27613, 27614, 27615, 27616, 27617, 27618, 27619, 27621, 27622, 27623, 27624, 27625, 27626, 27641, 27642, 27643, 27644, 27645, 27646, 28347, 29306, 29307, 29888, 32644, 32835, 32907, 32908, 33438, 34170, 34171, 35411, 35412, 36202, 36656, 38551, 38810, 39225, 39728, 39729, 39965, 40027, 40028, 40036, 40037, 40038, 40039, 40040, 40041, 40042, 40043, 40044, 40045, 40046, 40047, 40048, 40049, 40054, 41655, 41729, 43395, 43726, 44919, 45829, 46714, 46715, 46731, 46732, 46733, 47103, 47113, 47606, 48007, 48042, 48044, 48657, 48670, 50163, 50705, 50907, 51355, 51529, 51540, 51916, 52191, 54830, 57336, 57337, 57338, 57339, 57340, 58850, 59571, 59572, 63663, 64792, 65884, 65886, 66189, 67059, 67167, 68831, 72304, 73160, 74065, 74697, 75994, 77169, 78977, 80554, 80860, 80861, 80970, 83742, 84413, 84414, 84415, 84732, 84733, 84734, 84743, 84744, 86786, 89215, 89232, 90125, 90327, 94839] not in index'

# %%
ds_properati["barrio"].isna().sum()
# Out:
# 91715

# %% [markdown]
# Pasamos de tener 435 ciudades NaN a tener 384. Las que no pudieron ser reemplazadas o bien tienen latitud y longitud NaN (por lo que no pudimos imputar el barrio) o no son de CABA. Entonces, las eliminamos porque no son de interés.

# %%
ds_properati = ds_properati.loc[(ds_properati["barrio"].isna() == False)]
display(ds_properati["barrio"].isna().sum())
ds_properati.reset_index(drop=True, inplace=True)
ds_properati.head()
# Out:
# 0
#                          id  start_date    end_date  created_on    latitud  \
# 0  S8iZ1eflTJtt4bejzBVktw==  2021-09-09  2021-09-10  2021-09-09 -34.576741
# 1  FblpEe26U1lQkU5vRzAtmg==  2021-09-09  2021-09-09  2021-09-09 -34.576741
# 2  rPpA512CxIFuv8zDO9wrAQ==  2021-09-09  2021-11-16  2021-09-09 -34.579165
# 3  kokKfATispfpLcsX3xs6MA==  2021-09-09  2021-11-06  2021-09-09 -34.596098
# 4  QAdsaBdnyi7e1RV0VBj62w==  2021-09-09  2021-10-01  2021-09-09 -34.577044
#
#     longitud        provincia   ciudad         barrio place_l5  place_l6  \
# 0 -58.404830  Capital Federal  Palermo  Palermo Chico      NaN       NaN
# 1 -58.404830  Capital Federal  Palermo  Palermo Chico      NaN       NaN
# 2 -58.413458  Capital Federal  Palermo  Palermo Chico      NaN       NaN
# 3 -58.425662  Capital Federal  Palermo   Palermo Soho      NaN       NaN
# 4 -58.434030  Capital Federal  Palermo  Palermo Viejo      NaN       NaN
#
#   operation property_type  property_rooms  property_bedrooms  \
# 0     Venta  Departamento             NaN                4.0
# 1     Venta  Departamento             NaN                4.0
# 2     Venta  Departamento             4.0                2.0
# 3     Venta  Departamento             2.0                1.0
# 4     Venta  Departamento             2.0                2.0
#
#    property_surface_total  property_surface_covered  property_price  \
# 0                   400.0                       NaN       2700000.0
# 1                   400.0                       NaN       2700000.0
# 2                    85.0                      75.0        179999.0
# 3                    35.0                      33.0         85000.0
# 4                    41.0                      38.0        110000.0
#
#   property_currency                               property_title
# 0               USD                 Departamento - Palermo Chico
# 1               USD                 Departamento - Palermo Chico
# 2               USD                 Departamento - Palermo Chico
# 3               USD           Departamento 2 ambientes - Palermo
# 4               USD  2 Ambientes Frente Balcon, mts subte y tren

# %%
ds_agrupado_PL_3[:10].plot(kind = "barh", title="Frecuencia de valores de la variable barrio luego de la imputación", xlabel="frecuencia",ylabel="barrio")
# Out:
# <AxesSubplot: title={'center': 'Frecuencia de valores de la variable barrio luego de la imputación'}, xlabel='frecuencia', ylabel='barrio'>

# %% [markdown]
# ##### Imputación de coordenadas

# %% [markdown]
# De la misma manera, vamos a tomar las observaciones que tienen ciudad pero no coordenadas para imputarlas.

# %%
print(ds_properati[ds_properati["longitud"].isnull()].size) 
print(ds_properati[ds_properati["latitud"].isnull()].size)
# Out:
# 47021
# 47021

# %% [markdown]
# En todos los casos donde *latitud* es null también lo es *longitud*, por lo tanto filtramos por ambas coordenadas NaN y ciudad existente y agregamos la longitud/ latitud segun la ubicacion de la ciudad .

# %%
#sirven para graficar más adelante
latitud_antes = ds_properati['latitud']
longitud_antes = ds_properati['longitud']

# %%
ds_properati.loc[(ds_properati["latitud"].isna()) & (ds_properati["longitud"].isna())].shape
# Out:
# (3617, 13)

# %% [markdown]
# Primero calculamos el centroide para cada barrio.

# %%
poligonos["centroide_x"] = poligonos["geometry"].centroid.x
poligonos["centroide_y"] = poligonos["geometry"].centroid.y
#Grafico 
fig, ax = plt.subplots(figsize=(10,10))
poligonos.plot(ax=ax,column='BARRIO',alpha=0.8)
plt.scatter(poligonos.centroide_x, poligonos.centroide_y, color='red')

# %%
poligonos
# Out:
#                BARRIO  COMUNA     PERIMETRO          AREA  OBJETO  \
# 0           CHACARITA    15.0   7724.852955  3.115707e+06  BARRIO
# 1            PATERNAL    15.0   7087.513295  2.229829e+06  BARRIO
# 2        VILLA CRESPO    15.0   8131.857075  3.615978e+06  BARRIO
# 3    VILLA DEL PARQUE    11.0   7705.389797  3.399596e+06  BARRIO
# 4             ALMAGRO     5.0   8537.901368  4.050752e+06  BARRIO
# 5           CABALLITO     6.0  10990.964471  6.851029e+06  BARRIO
# 6    VILLA SANTA RITA    11.0   5757.752335  2.153691e+06  BARRIO
# 7        MONTE CASTRO    10.0   7361.036418  2.627481e+06  BARRIO
# 8          VILLA REAL    10.0   5070.965652  1.334146e+06  BARRIO
# 9              FLORES     7.0  15772.439510  8.590784e+06  BARRIO
# 10           FLORESTA    10.0   7519.654092  2.320641e+06  BARRIO
# 11       CONSTITUCION     1.0   6326.841375  2.101995e+06  BARRIO
# 12      SAN CRISTOBAL     3.0   5987.226479  2.043711e+06  BARRIO
# 13              BOEDO     5.0   6602.510266  2.609851e+06  BARRIO
# 14    VELEZ SARSFIELD    10.0   7045.578332  2.400518e+06  BARRIO
# 15         VILLA LURO    10.0   8652.930031  2.566937e+06  BARRIO
# 16   PARQUE PATRICIOS     4.0   7878.434993  3.743440e+06  BARRIO
# 17          MATADEROS     9.0  11124.635792  7.398179e+06  BARRIO
# 18       VILLA LUGANO     8.0  15057.468389  9.296142e+06  BARRIO
# 19          SAN TELMO     1.0   5178.032839  1.232270e+06  BARRIO
# 20           SAAVEDRA    12.0  11132.139346  5.538677e+06  BARRIO
# 21            COGHLAN    12.0   4627.563131  1.279951e+06  BARRIO
# 22      VILLA URQUIZA    12.0  10021.459665  5.449059e+06  BARRIO
# 23         COLEGIALES    13.0   6374.619045  2.289774e+06  BARRIO
# 24          BALVANERA     3.0   8375.821811  4.342280e+06  BARRIO
# 25  VILLA GRAL. MITRE    11.0   6290.440561  2.162275e+06  BARRIO
# 26        PARQUE CHAS    15.0   4531.253396  1.385412e+06  BARRIO
# 27          AGRONOMIA    15.0   6556.167772  2.122169e+06  BARRIO
# 28      VILLA ORTUZAR    15.0   5684.995211  1.853802e+06  BARRIO
# 29           BARRACAS     4.0  12789.791771  7.953453e+06  BARRIO
# 30  PARQUE AVELLANEDA     9.0  10165.614028  4.732708e+06  BARRIO
# 31   PARQUE CHACABUCO     7.0   8406.914321  3.832117e+06  BARRIO
# 32      NUEVA POMPEYA     4.0  11033.510302  4.951511e+06  BARRIO
# 33            PALERMO    14.0  22126.531858  1.584587e+07  BARRIO
# 34    VILLA RIACHUELO     8.0  10596.826739  4.232596e+06  BARRIO
# 35      VILLA SOLDATI     8.0  12441.695877  8.688164e+06  BARRIO
# 36   VILLA PUEYRREDON    12.0   7522.360382  3.303240e+06  BARRIO
# 37       VILLA DEVOTO    11.0  11562.006800  6.404481e+06  BARRIO
# 38            LINIERS     9.0   9256.927321  4.374419e+06  BARRIO
# 39          VERSALLES    10.0   5650.466286  1.406834e+06  BARRIO
# 40      PUERTO MADERO     1.0  17725.720821  5.040971e+06  BARRIO
# 41          MONSERRAT     1.0   6739.222311  2.198622e+06  BARRIO
# 42        SAN NICOLAS     1.0   6548.084754  2.289008e+06  BARRIO
# 43           BELGRANO    13.0  20609.775397  7.999240e+06  BARRIO
# 44           RECOLETA     2.0  21452.838648  6.317265e+06  BARRIO
# 45             RETIRO     1.0  18837.988687  4.512711e+06  BARRIO
# 46              NUÑEZ    13.0  10785.261081  4.424199e+06  BARRIO
# 47               BOCA     4.0  20060.003939  5.036240e+06  BARRIO
#
#                                              geometry  centroide_x  \
# 0   MULTIPOLYGON (((-58.45282 -34.59599, -58.45366...   -58.454180
# 1   MULTIPOLYGON (((-58.46558 -34.59656, -58.46562...   -58.468665
# 2   MULTIPOLYGON (((-58.42375 -34.59783, -58.42495...   -58.442725
# 3   MULTIPOLYGON (((-58.49461 -34.61487, -58.49479...   -58.490677
# 4   MULTIPOLYGON (((-58.41287 -34.61412, -58.41282...   -58.421745
# 5   MULTIPOLYGON (((-58.43061 -34.60705, -58.43056...   -58.443603
# 6   MULTIPOLYGON (((-58.48192 -34.62429, -58.48274...   -58.482957
# 7   MULTIPOLYGON (((-58.50349 -34.62403, -58.50467...   -58.506581
# 8   MULTIPOLYGON (((-58.52512 -34.61400, -58.52511...   -58.526039
# 9   MULTIPOLYGON (((-58.46041 -34.65680, -58.46090...   -58.458268
# 10  MULTIPOLYGON (((-58.48339 -34.62411, -58.48274...   -58.483588
# 11  MULTIPOLYGON (((-58.37557 -34.62730, -58.37660...   -58.384388
# 12  MULTIPOLYGON (((-58.39155 -34.62156, -58.39149...   -58.401884
# 13  MULTIPOLYGON (((-58.41178 -34.63036, -58.41178...   -58.418840
# 14  MULTIPOLYGON (((-58.48557 -34.63140, -58.48473...   -58.493277
# 15  MULTIPOLYGON (((-58.50154 -34.63183, -58.50104...   -58.502729
# 16  MULTIPOLYGON (((-58.41037 -34.64830, -58.41210...   -58.401675
# 17  MULTIPOLYGON (((-58.50252 -34.67451, -58.50253...   -58.501737
# 18  MULTIPOLYGON (((-58.46571 -34.65903, -58.46519...   -58.476167
# 19  MULTIPOLYGON (((-58.36345 -34.62512, -58.36649...   -58.371541
# 20  MULTIPOLYGON (((-58.48813 -34.56129, -58.48827...   -58.488745
# 21  MULTIPOLYGON (((-58.47242 -34.56610, -58.47296...   -58.474944
# 22  MULTIPOLYGON (((-58.48098 -34.56264, -58.48023...   -58.487856
# 23  MULTIPOLYGON (((-58.44669 -34.56907, -58.44650...   -58.450968
# 24  MULTIPOLYGON (((-58.41192 -34.59800, -58.41029...   -58.403062
# 25  MULTIPOLYGON (((-58.47140 -34.61904, -58.47162...   -58.468943
# 26  MULTIPOLYGON (((-58.47082 -34.58745, -58.47082...   -58.479121
# 27  MULTIPOLYGON (((-58.47712 -34.59511, -58.47788...   -58.488673
# 28  MULTIPOLYGON (((-58.46055 -34.57794, -58.46022...   -58.467651
# 29  MULTIPOLYGON (((-58.37034 -34.63293, -58.37028...   -58.384272
# 30  MULTIPOLYGON (((-58.47038 -34.63879, -58.47001...   -58.476455
# 31  MULTIPOLYGON (((-58.43234 -34.64174, -58.43231...   -58.437696
# 32  MULTIPOLYGON (((-58.41221 -34.64813, -58.41210...   -58.418882
# 33  MULTIPOLYGON (((-58.42676 -34.55202, -58.42676...   -58.422342
# 34  MULTIPOLYGON (((-58.44978 -34.68061, -58.44863...   -58.463350
# 35  MULTIPOLYGON (((-58.44913 -34.65117, -58.44883...   -58.446587
# 36  MULTIPOLYGON (((-58.50331 -34.59386, -58.50347...   -58.503499
# 37  MULTIPOLYGON (((-58.50831 -34.61392, -58.50847...   -58.514282
# 38  MULTIPOLYGON (((-58.51925 -34.63301, -58.51908...   -58.519128
# 39  MULTIPOLYGON (((-58.51104 -34.63256, -58.51010...   -58.522417
# 40  MULTIPOLYGON (((-58.35196 -34.59817, -58.35179...   -58.355689
# 41  MULTIPOLYGON (((-58.36880 -34.60683, -58.36815...   -58.379648
# 42  MULTIPOLYGON (((-58.36792 -34.60517, -58.36773...   -58.380515
# 43  MULTIPOLYGON (((-58.45057 -34.53561, -58.45066...   -58.450241
# 44  MULTIPOLYGON (((-58.38000 -34.57002, -58.38002...   -58.394929
# 45  MULTIPOLYGON (((-58.37427 -34.57870, -58.37427...   -58.375994
# 46  MULTIPOLYGON (((-58.45872 -34.53721, -58.45887...   -58.462751
# 47  MULTIPOLYGON (((-58.35429 -34.62977, -58.35427...   -58.356819
#
#     centroide_y
# 0    -34.588369
# 1    -34.597421
# 2    -34.598830
# 3    -34.604247
# 4    -34.609227
# 5    -34.616825
# 6    -34.616193
# 7    -34.619298
# 8    -34.619493
# 9    -34.636803
# 10   -34.627686
# 11   -34.625044
# 12   -34.623865
# 13   -34.629960
# 14   -34.631361
# 15   -34.636413
# 16   -34.637550
# 17   -34.658373
# 18   -34.674993
# 19   -34.621520
# 20   -34.553076
# 21   -34.560624
# 22   -34.571541
# 23   -34.574642
# 24   -34.609099
# 25   -34.610029
# 26   -34.585523
# 27   -34.592945
# 28   -34.580973
# 29   -34.646403
# 30   -34.648642
# 31   -34.635940
# 32   -34.650515
# 33   -34.573855
# 34   -34.691858
# 35   -34.665421
# 36   -34.582103
# 37   -34.602355
# 38   -34.643796
# 39   -34.630123
# 40   -34.609050
# 41   -34.612686
# 42   -34.603666
# 43   -34.554763
# 44   -34.585778
# 45   -34.588397
# 46   -34.543481
# 47   -34.631070

# %%
ds_properati['barrio'] = ds_properati['barrio'].str.upper() #paso a mayúscula para que coincida con los polígonos
ds_copia = ds_properati.copy()
ds_coord_nan = ds_copia.loc[(ds_copia["barrio"].isna() == False) & (ds_copia["latitud"].isna()) & (ds_copia["longitud"].isna())]
 
for barrio in poligonos.BARRIO:
    b = poligonos[poligonos['BARRIO'] == barrio].index[0]
    
    lat = poligonos.loc[b, 'centroide_y']
    lon = poligonos.loc[b, 'centroide_x']
    
    ds_coord_nan.loc[(ds_coord_nan["barrio"] == barrio), "latitud"] = lat
    ds_coord_nan.loc[(ds_coord_nan["barrio"] == barrio), "longitud"] = lat

ds_properati.loc[ds_coord_nan.index] = ds_coord_nan
ds_properati.head()
# Out:
#    created_on    latitud   longitud        provincia barrio operation  \
# 0  2021-09-09 -34.637319 -58.361124  Capital Federal   BOCA     Venta
# 1  2021-09-09 -34.628647 -58.361871  Capital Federal   BOCA     Venta
# 2  2021-09-09 -34.599506 -58.404138  Capital Federal   ONCE     Venta
# 3  2021-09-09 -34.610027 -58.401934  Capital Federal   ONCE     Venta
# 4  2021-09-09 -34.631621 -58.416825  Capital Federal  BOEDO     Venta
#
#   property_type  property_rooms  property_bedrooms  property_surface_total  \
# 0  Departamento             3.0                2.0                    58.0
# 1  Departamento             4.0                3.0                    70.0
# 2  Departamento             2.0                1.0                    43.0
# 3  Departamento             4.0                2.0                     NaN
# 4            PH             4.0                2.0                     NaN
#
#    property_surface_covered  property_price property_currency
# 0                      55.0         82900.0               USD
# 1                      70.0         99000.0               USD
# 2                      43.0             NaN               NaN
# 3                     104.0        146000.0               USD
# 4                      73.0        250000.0               USD

# %% [markdown]
# Ahora veamos si quedó algun valor sin imputar.

# %%
sin_coord = ds_properati.loc[(ds_properati["latitud"].isna()) & (ds_properati["longitud"].isna())]
sin_coord.shape
# Out:
# (382, 13)

# %% [markdown]
# Tenemos 382 filas de las 3617 originales que quedaron NaN. Veamos por qué:

# %%
display(sin_coord.barrio.unique())
display(poligonos["BARRIO"].unique())
# Out:
# array(['BARRIO NORTE', 'SAN NICOLÁS', 'VILLA PUEYRREDÓN', 'ONCE',
#        'CONGRESO', 'ABASTO', 'TRIBUNALES', 'CONSTITUCIÓN',
#        'VILLA GENERAL MITRE', 'POMPEYA', 'AGRONOMÍA', 'PARQUE CENTENARIO',
#        'CENTRO / MICROCENTRO'], dtype=object)
# array(['CHACARITA', 'PATERNAL', 'VILLA CRESPO', 'VILLA DEL PARQUE',
#        'ALMAGRO', 'CABALLITO', 'VILLA SANTA RITA', 'MONTE CASTRO',
#        'VILLA REAL', 'FLORES', 'FLORESTA', 'CONSTITUCION',
#        'SAN CRISTOBAL', 'BOEDO', 'VELEZ SARSFIELD', 'VILLA LURO',
#        'PARQUE PATRICIOS', 'MATADEROS', 'VILLA LUGANO', 'SAN TELMO',
#        'SAAVEDRA', 'COGHLAN', 'VILLA URQUIZA', 'COLEGIALES', 'BALVANERA',
#        'VILLA GRAL. MITRE', 'PARQUE CHAS', 'AGRONOMIA', 'VILLA ORTUZAR',
#        'BARRACAS', 'PARQUE AVELLANEDA', 'PARQUE CHACABUCO',
#        'NUEVA POMPEYA', 'PALERMO', 'VILLA RIACHUELO', 'VILLA SOLDATI',
#        'VILLA PUEYRREDON', 'VILLA DEVOTO', 'LINIERS', 'VERSALLES',
#        'PUERTO MADERO', 'MONSERRAT', 'SAN NICOLAS', 'BELGRANO',
#        'RECOLETA', 'RETIRO', 'NUÑEZ', 'BOCA'], dtype=object)

# %% [markdown]
# Las diferencias acá son:
#
# - ONCE es parte de BALVANERA
# - BARRIO NORTE comprende parte de los barrios RETIRO y RECOLETA
# - SAN NICOLÁS, VILLA PUEYRREDÓN y CONSTITUCIÓN aparecen sin tilde
# - CONGRESO es zona este de BALVANERA
# - ABASTO es un sub-barrio de BALVANERA (aunque también toma parte de ALMAGRO)
# - TRIBUNALES es parte de SAN NICOLAS
# - VILLA GENERAL MITRE aparece como VILLA GRAL. MITRE
# - POMPEYA es NUEVA POMPEYA
# - PARQUE CENTENARIO corresponde a CABALLITO
# - MICROCENTRO es parte de SAN NICOLAS
#
# Teniendo esto en cuenta aplicaremos los cambios correspondientes para que haya unicidad en los nombres e imputaremos las coordenadas nuevamente.

# %%
ds_copia = ds_properati.copy()
ds_coord_nans = ds_copia.loc[(ds_copia["latitud"].isna()) & (ds_copia["longitud"].isna())]

ds_coord_nans['barrio'].replace({'TRIBUNALES':'SAN NICOLAS', 'VILLA GENERAL MITRE':'VILLA GRAL. MITRE', 'POMPEYA':'NUEVA POMPEYA', 'PARQUE CENTENARIO':'CABALLITO','ONCE':'BALVANERA','SAN NICOLÁS':'SAN NICOLAS', 'VILLA PUEYRREDÓN':'VILLA PUEYRREDON', 'CONSTITUCIÓN':'CONSTITUCION', 'CONGRESO':'BALVANERA','CENTRO / MICROCENTRO':'SAN NICOLAS', 'ABASTO':'BALVANERA', 'BARRIO NORTE':'RECOLETA', 'AGRONOMÍA': 'AGRONOMIA'}, inplace=True)

for barrio in poligonos.BARRIO:
    b = poligonos[poligonos['BARRIO'] == barrio].index[0]
    lat = poligonos.loc[b, 'centroide_y']
    lon = poligonos.loc[b, 'centroide_x']
    ds_coord_nans.loc[(ds_coord_nans["barrio"] == barrio), "latitud"] = lat
    ds_coord_nans.loc[(ds_coord_nans["barrio"] == barrio), "longitud"] = lat

ds_properati.loc[ds_properati.loc[ds_coord_nans.index].index, 'latitud'] = ds_coord_nans['latitud']
ds_properati.loc[ds_properati.loc[ds_coord_nans.index].index, 'longitud'] = ds_coord_nans['longitud']

# %%
display(ds_properati['latitud'].isna().sum())
display(ds_properati['longitud'].isna().sum())
# Out:
# 0
# 0

# %% [markdown]
# Finalmente reemplazamos todos los NaN de latitud y longitud. Realizamos un gráfico para ver si distribución luego de la imputación.

# %%
df_comparado = pd.DataFrame({"latitud antes":latitud_antes,"latitud despues":ds_properati['latitud']})
ax = df_comparado[["latitud antes","latitud despues"]].plot(kind= "box",title="Boxplot variable latitud antes y despues de imputación",showfliers=False,ylabel="grados")
plt.show()

# %% [markdown]
# ##### Imputación de los valores nans de la categoría *bedrooms*

# %% [markdown]
# Tomamos en cuenta la media de dormitorios de cada uno de los diferentes ambientes (10 ambientes en total)

# %%
medias_bedrooms = []
repeticiones = 0
for cant in range(1,11): #hasta 10 ambientes dado el analisis de más adelante de outliers
    ds_copia = ds_properati.copy()
    copia_con_cant_ambientes = ds_copia.loc[ds_copia["property_rooms"]==cant]
    medias_bedrooms.append(round(copia_con_cant_ambientes["property_bedrooms"].mean()))
medias_bedrooms
# Out:
# [1, 1, 2, 3, 4, 4, 4, 5, 5, 6]

# %% [markdown]
# Como ya tenemos la media de las habitaciones por cada ambientes, procedemos a imputarlas

# %%
prop_nan = ds_properati.loc[ds_properati["property_bedrooms"].isna()]

ds_property_bedrooms_antes = ds_properati["property_bedrooms"]
for index,row in prop_nan.iterrows():
    cantidad = row["property_rooms"]
    if cantidad < 11:
        ds_properati.loc[index,"property_bedrooms"] = medias_bedrooms[int(cantidad)-1]

# %%
ds_properati["property_rooms"].unique()
# Out:
# array([ 3.,  4.,  2., 10.,  5.,  1., nan,  6.,  7.,  9.,  8., 15., 11.,
#        12., 30., 19., 13., 14., 32., 17., 36., 35., 28., 18., 20., 16.,
#        24., 40.])

# %% [markdown]
# Le imputamos una habitación a todos los registros que sigan sin tener datos de las habitaciones. (Que son aquellos con más de 10 ambientes)

# %%
ds_properati["property_bedrooms"] = ds_properati['property_bedrooms'].fillna(1)

# %% [markdown]
# Como en property_bedrooms, imputamos los ambientes según la media de las habitaciones.

# %%
ds_property_rooms_antes = ds_properati["property_rooms"]
medias_rooms = []
for cant in range(1,11):
    ds_copia = ds_properati.copy()
    copia_con_cant_habitaciones = ds_copia.loc[ds_copia["property_bedrooms"]==cant]
    medias_rooms.append(round(copia_con_cant_habitaciones["property_rooms"].mean()))
medias_rooms
# Out:
# [2, 3, 4, 5, 7, 8, 8, 9, 11, 11]

# %%
prop_rooms_nan = ds_properati.loc[ds_properati["property_rooms"].isna()]

ds_property_bedrooms_antes = ds_properati["property_bedrooms"]
for index,row in prop_rooms_nan.iterrows():
    cantidad = row["property_bedrooms"]
    if cantidad < 11:
        ds_properati.loc[index,"property_rooms"] = medias_rooms[int(cantidad)-1]

# %%
ds_properati["property_rooms"].unique()
# Out:
# array([ 3.,  4.,  2., 10.,  5.,  1.,  6.,  7.,  9.,  8., 15., 11., 12.,
#        nan, 30., 19., 13., 14., 32., 17., 36., 35., 28., 18., 20., 16.,
#        24., 40.])

# %% [markdown]
# ##### Property_surface_total y property_surface_covered

# %% [markdown]
# Para las columnas de property_surface_total y property_surface_covered adquirimos la estategia de la opcion 3 adoptando la media de sus valores totales no faltantes:

# %%
prop_surface_total_antes = ds_properati["property_surface_total"]
prop_surface_covered_antes = ds_properati["property_surface_covered"]
ds_properati["property_surface_total"] = ds_properati['property_surface_total'].fillna(ds_properati['property_surface_total'].mean())
ds_properati["property_surface_covered"] = ds_properati['property_surface_covered'].fillna(ds_properati['property_surface_covered'].mean())

# %% [markdown]
# ##### Análisis de valores faltantes en *currency*

# %% [markdown]
# Revisaremos de qué manera podríamos deducir la moneda que le corresponde a una propiedad. Para poder determinarlo, mínimamente deberíamos contar con el precio de la propiedad de manera de poder entender en qué moneda podría estar.

# %%
ds_currency_nan = ds_properati.loc[ds_properati.property_currency.isna()]
ds_currency_nan.head()
# Out:
#      created_on    latitud   longitud        provincia        barrio  \
# 2    2021-09-09 -34.599506 -58.404138  Capital Federal          ONCE
# 96   2021-09-09 -34.552724 -58.464948  Capital Federal      BELGRANO
# 743  2021-02-20 -34.626710 -58.448553  Capital Federal     CABALLITO
# 772  2021-02-20 -34.597851 -58.410105  Capital Federal  BARRIO NORTE
# 910  2021-09-20 -34.581687 -58.422602  Capital Federal       PALERMO
#
#     operation property_type  property_rooms  property_bedrooms  \
# 2       Venta  Departamento             2.0                1.0
# 96      Venta  Departamento             2.0                2.0
# 743     Venta  Departamento             3.0                2.0
# 772     Venta  Departamento             3.0                2.0
# 910     Venta  Departamento             2.0                1.0
#
#      property_surface_total  property_surface_covered  property_price  \
# 2                      43.0                      43.0             NaN
# 96                     60.0                      50.0             NaN
# 743                    65.0                      65.0             NaN
# 772                   141.0                      59.0             NaN
# 910                    61.0                      56.0             NaN
#
#     property_currency
# 2                 NaN
# 96                NaN
# 743               NaN
# 772               NaN
# 910               NaN

# %%
display(ds_currency_nan.shape)
ds_price = ds_currency_nan.loc[ds_currency_nan.property_price.isna()]
display(ds_price.shape)
# Out:
# (1228, 13)
# (1171, 13)

# %% [markdown]
# Tenemos 507 registros que no tienen precio por lo cual no tenemos forma de predecir qué moneda le corresponde. Estas filas las eliminamos.

# %%
ds_properati.drop(ds_price.index, inplace=True)

# %% [markdown]
# Las restantes que sí poseen precio las vamos a examinar más en detalle.

# %%
ds_currency_nan = ds_properati.loc[ds_properati.property_currency.isna()]
ds_currency_nan.property_price.unique()
# Out:
# array([0.])

# %% [markdown]
# Tenemos que el precio que les figura es cero. Por el momento lo dejaremos así dado que los valores atípicos de price lo trataremos unas celdas más abajo.

# %% [markdown]
# ##### Conclusiones

# %% [markdown]
# Ahora podemos ver como queda el porcentaje de valores nans respecto del total del data set

# %%
porcentajes = ds_properati.isna().sum() / len(ds_properati) * 100
porcentajes
# Out:
# created_on                  0.000000
# latitud                     0.000000
# longitud                    0.000000
# provincia                   0.000000
# barrio                      0.000000
# operation                   0.000000
# property_type               0.000000
# property_rooms              0.007452
# property_bedrooms           0.000000
# property_surface_total      0.000000
# property_surface_covered    0.000000
# property_price              0.000000
# property_currency           0.060677
# dtype: float64

# %% [markdown]
# Podemos mostrar como quedan los datos antes y despues de las imputaciones, como por ejemplo los casos de property_surface_total, property_surface_covered, property_bedrooms o property_rooms

# %%
df_comparado = pd.DataFrame({"property_surface_total antes":prop_surface_total_antes,"property_surface_total después":ds_properati['property_surface_total']})
ax = df_comparado[["property_surface_total antes","property_surface_total después"]].plot(kind= "box",title="Boxplot variable property_surface_total antes y después de imputación",showfliers=False,ylabel="metros cuadrados")
plt.show()

# %% [markdown]
# Se puede ver que removiendo los outliers, queda un boxplot parecido ya que estamos hallando la media de todos los valores. Igualmente si inspeccionamos minusiosamente, podemos ver que el gráfico de la derecha se encuentra mas grande. Pero se podría decir que no cambia mayormente la distribución de los datos tomando la media para los datos faltantes.

# %% [markdown]
# Lo mismo se podria decir para el caso de property_surface_covered o property_rooms al agregar los datos faltantes por la media de los datos no faltantes.

# %%
df_comparado = pd.DataFrame({"property_surface_covered antes":prop_surface_covered_antes,"property_surface_covered después":ds_properati['property_surface_covered']})
ax = df_comparado[["property_surface_covered antes","property_surface_covered después"]].plot(kind= "box",title="Boxplot variable property_surface_covered antes y despues de imputacion",showfliers=False,ylabel="metros cuadrados")
plt.show()

# %%
df_comparado = pd.DataFrame({"property_rooms antes":ds_property_rooms_antes,"property_rooms después":ds_properati['property_rooms']})
ax = df_comparado[["property_rooms antes","property_rooms después"]].plot(kind= "box",title="Boxplot variable property_rooms antes y después de imputación",showfliers=False,ylabel="cant de ambientes")
plt.show()

# %%
df_comparado = pd.DataFrame({"property_bedrooms antes":ds_property_bedrooms_antes,"property_bedrooms después":ds_properati['property_bedrooms']})
ax = df_comparado[["property_bedrooms antes","property_bedrooms después"]].plot(kind= "box",title="Boxplot variable property_bedrooms antes y después de imputación",showfliers=False,ylabel="cant de habitaciones")
plt.show()

# %% [markdown]
# #### Busqueda Valores Atípicos - Univariados

# %% [markdown]
# Haciendo boxplots se realiza el análisis de valores atípicos en forma univariada

# %% [markdown]
# ##### Outliers coordenadas

# %%
#Valores atipicos en la latitud:
sns.boxplot(y=ds_properati.latitud)
plt.show()

# %% [markdown]
# Como se puede observar, la abrumadora mayoría de propiedades en venta se encuentran sobre una latitud sur de alrededor de -34º, lo cual coincide con la ubicación geográfica de la Ciudad Autónoma de Buenos Aires. Sin embargo, vemos valores atípicos después de los -34.675°. A primera impresión podrían resultar outliers pero consultando los polígonos, el barrio de Villa Riachuelo presenta la coordenada de latitud más baja con aproximadamente -34.7053°. Asi que no son valores atípicos, están dentro del rango posible.

# %%
poligonos.plot

# %%
#Boxplot de la variable longitud
sns.boxplot(y=ds_properati.longitud)
plt.show()

# %% [markdown]
# Lo mismo sucede con la longitud. La Ciudad Autónoma de Buenos Aires se encuentra a una longitud oeste de ≈-58.43º, lo cual coincide con la gran mayoría de datos (comparando con el boxplot). Se observan outliers en ≈-35° valor que ahora sí no es correcto.

# %%
ds_properati[ds_properati["longitud"] > -40]
# Out:
#        created_on    latitud   longitud        provincia        barrio  \
# 44     2021-09-09 -34.573855 -34.573855  Capital Federal       PALERMO
# 73     2021-09-09 -34.573855 -34.573855  Capital Federal       PALERMO
# 74     2021-09-09 -34.573855 -34.573855  Capital Federal       PALERMO
# 99     2021-09-09 -34.554763 -34.554763  Capital Federal      BELGRANO
# 104    2021-09-09 -34.627686 -34.627686  Capital Federal      FLORESTA
# ...           ...        ...        ...              ...           ...
# 94966  2021-01-05 -34.585778 -34.585778  Capital Federal      RECOLETA
# 95044  2021-01-05 -34.585778 -34.585778  Capital Federal  BARRIO NORTE
# 95045  2021-01-05 -34.585778 -34.585778  Capital Federal  BARRIO NORTE
# 95050  2021-01-05 -34.603666 -34.603666  Capital Federal   SAN NICOLÁS
# 95071  2021-01-05 -34.674993 -34.674993  Capital Federal  VILLA LUGANO
#
#       operation property_type  property_rooms  property_bedrooms  \
# 44        Venta  Departamento             3.0                2.0
# 73        Venta  Departamento             2.0                1.0
# 74        Venta  Departamento             3.0                2.0
# 99        Venta  Departamento             4.0                3.0
# 104       Venta          Casa             5.0                4.0
# ...         ...           ...             ...                ...
# 94966     Venta  Departamento             6.0                4.0
# 95044     Venta  Departamento             3.0                2.0
# 95045     Venta  Departamento             3.0                2.0
# 95050     Venta  Departamento             4.0                2.0
# 95071     Venta  Departamento             3.0                2.0
#
#        property_surface_total  property_surface_covered  property_price  \
# 44                       85.0                      85.0        200000.0
# 73                       50.0                      50.0        153000.0
# 74                      185.0                     185.0        890000.0
# 99                      180.0                     103.0        495000.0
# 104                     165.0                     115.0        185000.0
# ...                       ...                       ...             ...
# 94966                   169.0                     159.0        450000.0
# 95044                   115.0                     108.0        310000.0
# 95045                    54.0                      50.0        165000.0
# 95050                   110.0                     110.0        295000.0
# 95071                    49.0                      49.0         39900.0
#
#       property_currency
# 44                  USD
# 73                  USD
# 74                  USD
# 99                  USD
# 104                 USD
# ...                 ...
# 94966               USD
# 95044               USD
# 95045               USD
# 95050               USD
# 95071               USD
#
# [3562 rows x 13 columns]

# %%
ds_lon_mal = ds_properati[ds_properati["longitud"] > -40]

#por las dudas reemplazamos las localidades que pertenecen a otros barrios o que están escritas diferente en el GeoDataFrame
ds_lon_mal['barrio'].replace({'TRIBUNALES':'SAN NICOLAS', 'VILLA GENERAL MITRE':'VILLA GRAL. MITRE', 'POMPEYA':'NUEVA POMPEYA', 'PARQUE CENTENARIO':'CABALLITO','ONCE':'BALVANERA','SAN NICOLÁS':'SAN NICOLAS', 'VILLA PUEYRREDÓN':'VILLA PUEYRREDON', 'CONSTITUCIÓN':'CONSTITUCION', 'CONGRESO':'BALVANERA','CENTRO / MICROCENTRO':'SAN NICOLAS', 'ABASTO':'BALVANERA', 'BARRIO NORTE':'RECOLETA', 'AGRONOMÍA': 'AGRONOMIA'}, inplace=True)

for barrio in poligonos.BARRIO:
    b = poligonos[poligonos['BARRIO'] == barrio].index[0]
    ds_lon_mal.loc[(ds_lon_mal["barrio"] == barrio), "longitud"] = poligonos.loc[b, 'centroide_x']

ds_properati.loc[ds_properati.loc[ds_lon_mal.index].index, 'longitud'] = ds_lon_mal['longitud']

# %%
ds_properati[ds_properati["longitud"] > -40].shape[0]
# Out:
# 0

# %% [markdown]
# Ahora sí no quedan valores atípicos en las longitudes.

# %% [markdown]
# ##### Outliers en los campos de superficie

# %% [markdown]
# Para evaluar la existencia de outliers en los campos de superficie, se decide realizar 3 gráficos por separado, en función del tipo de propiedad. Esto se realiza debido a que es de esperarse que una casa pueda llegar a tener más superficie cubierta y total que un departamento.

# %%
#Boxplot de la variable property_surface_covered
sns.boxplot(x=ds_properati.property_type, y=ds_properati.property_surface_covered)
plt.show()

# %% [markdown]
# Analizamos los potenciales outliers para cada uno de los tipos de propiedad haciendo uso del z-score modificado. Cada vez que se llama a la función zscore, se imprime la cantidad de outliers hallados.

# %%
def zscore(campo):
    casa = ds_properati[ds_properati['property_type'] == "Casa"]
    dpto = ds_properati[ds_properati['property_type'] == "Departamento"]
    ph = ds_properati[ds_properati['property_type'] == "PH"]

    #Cuartiles
    Q1_sup_cubierta_casa = np.quantile(casa[campo], 0.25)
    Q3_sup_cubierta_casa = np.quantile(casa[campo], 0.75)

    Q1_sup_cubierta_dpto = np.quantile(dpto[campo], 0.25)
    Q3_sup_cubierta_dpto = np.quantile(dpto[campo], 0.75)

    Q1_sup_cubierta_ph = np.quantile(ph[campo], 0.25)
    Q3_sup_cubierta_ph = np.quantile(ph[campo], 0.75)

    #Rango intercuartil
    IQR_sup_cubierta_casa = Q3_sup_cubierta_casa - Q1_sup_cubierta_casa
    IQR_sup_cubierta_dpto = Q3_sup_cubierta_dpto - Q1_sup_cubierta_dpto
    IQR_sup_cubierta_ph = Q3_sup_cubierta_ph - Q1_sup_cubierta_ph

    #Límite inferior
    out_inf_casa = Q1_sup_cubierta_casa - 1.5 * IQR_sup_cubierta_casa
    out_sup_casa = Q3_sup_cubierta_casa + 1.5 * IQR_sup_cubierta_casa

    out_inf_dpto = Q1_sup_cubierta_dpto - 1.5 * IQR_sup_cubierta_dpto
    out_sup_dpto = Q3_sup_cubierta_dpto + 1.5 * IQR_sup_cubierta_dpto

    out_inf_ph = Q1_sup_cubierta_ph - 1.5 * IQR_sup_cubierta_ph
    out_sup_ph = Q3_sup_cubierta_ph + 1.5 * IQR_sup_cubierta_ph

    #Z-Score modificado
    mediana_sup_cubierta_casa = np.median(casa[campo])
    MAD = np.median(np.absolute(casa[campo] - mediana_sup_cubierta_casa))
    casa['zm_sup_cubierta'] = (casa[campo] - mediana_sup_cubierta_casa) * 0.6745 / MAD

    mediana_sup_cubierta_dpto = np.median(dpto[campo])
    MAD = np.median(np.absolute(dpto[campo] - mediana_sup_cubierta_dpto))
    dpto['zm_sup_cubierta'] = (dpto[campo] - mediana_sup_cubierta_dpto) * 0.6745 / MAD

    mediana_sup_cubierta_ph = np.median(ph[campo])
    MAD = np.median(np.absolute(ph[campo] - mediana_sup_cubierta_ph))
    ph['zm_sup_cubierta'] = (ph[campo] - mediana_sup_cubierta_ph) * 0.6745 / MAD

    print(casa[casa['zm_sup_cubierta'] >= 3.5].shape)
    print(dpto[dpto['zm_sup_cubierta'] >= 3.5].shape)
    print(ph[ph['zm_sup_cubierta'] >= 3.5].shape)

    return casa, dpto, ph

# %% [markdown]
# Eliminamos aquellos valores que son outliers.

# %%
casa, dpto, ph = zscore("property_surface_covered")

ds_properati.drop(casa[casa['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(dpto[dpto['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(ph[ph['zm_sup_cubierta'] >= 3.5].index, inplace = True)
# Out:
# (185, 14)
# (4964, 14)
# (345, 14)

# %% [markdown]
# Se puede observar a continuación un boxplot con valores realistas y concentrados. A su vez, como era de esperarse, las casas en promedio son más grandes que los PHs y los departamentos.

# %%
#Boxplot de la variable property_surface_covered
sns.boxplot(x=ds_properati.property_type, y=ds_properati.property_surface_covered)
plt.show()

# %% [markdown]
# Repitiendo el mismo proceso para la superficie total, se pueden observar varios outliers, principalmente en las entradas de departamentos.

# %%
#Boxplot de la variable property_surface_total
sns.boxplot(x=ds_properati.property_type, y=ds_properati.property_surface_total)
plt.show()

# %% [markdown]
# Aplicando z-score modificado.

# %%
casa, dpto, ph = zscore('property_surface_total')

ds_properati.drop(casa[casa['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(dpto[dpto['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(ph[ph['zm_sup_cubierta'] >= 3.5].index, inplace = True)
# Out:
# (56, 14)
# (1309, 14)
# (151, 14)

# %% [markdown]
# Nuevamente, se puede observar una distribución más equilibrada y realista.

# %%
#Boxplot de la variable property_surface_total sin outliers
sns.boxplot(x=ds_properati.property_type, y=ds_properati.property_surface_total)
plt.show()

# %% [markdown]
# Repitiendo idea y procedimiento con el precio de las propiedades.

# %%
#Boxlot de la variable property_price
sns.boxplot(x=ds_properati.property_type, y=ds_properati.property_price)
plt.show()

# %% [markdown]
# Aplicando el mismo concepto para el precio de las propiedades...

# %%
casa, dpto, ph = zscore('property_price')

ds_properati.drop(casa[casa['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(dpto[dpto['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(ph[ph['zm_sup_cubierta'] >= 3.5].index, inplace = True)
# Out:
# (164, 14)
# (4224, 14)
# (136, 14)

# %%
#Boxlot de la variable property_price sin outliers
sns.boxplot(x=ds_properati.property_type, y=ds_properati.property_price)
plt.show()

# %% [markdown]
# Ahora para la cantidad de ambientes y dormitorios.

# %%
#Histograma de la variable cantidad de ambientes
plt.title('Distribución de cantidad de ambientes')
plt.hist(ds_properati['property_rooms'], alpha = 0.5) 
plt.xlabel("Cantidad de Ambientes")
plt.ylabel("Ocurrencias")
plt.grid(True)
plt.show()

# %%
casa, dpto, ph = zscore('property_rooms')

ds_properati.drop(casa[casa['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(dpto[dpto['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(ph[ph['zm_sup_cubierta'] >= 3.5].index, inplace = True)
# Out:
# (0, 14)
# (11, 14)
# (7, 14)

# %%
#Histograma de la variable cantidad de ambientes sin outliers
plt.title('Distribución de cantidad de ambientes')
plt.hist(ds_properati['property_rooms'], alpha = 0.5) 
plt.xlabel("Cantidad de Ambientes")
plt.ylabel("Ocurrencias")
plt.grid(True)
plt.show()

# %%
#Histograma de la variable cantidad de dormitorios
#sns_hist = sns.histplot(data=ds_properati['property_bedrooms'], alpha = 0.5, binwidth=1).set(title="Distribución de Cantidad de Dormitorios",xlabel="Cantidad de Dormitorios",ylabel="Ocurrencias")

# %%
casa, dpto, ph = zscore('property_bedrooms')

ds_properati.drop(casa[casa['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(dpto[dpto['zm_sup_cubierta'] >= 3.5].index, inplace = True)
ds_properati.drop(ph[ph['zm_sup_cubierta'] >= 3.5].index, inplace = True)
# Out:
# (19, 14)
# (30523, 14)
# (0, 14)

# %% [markdown]
# Mostramos el resultado del análisis de outliers en un histograma

# %%
#sns_hist = s.histplot(data=ds_properati['property_rooms'], alpha = 0.5, binwidth=1).set(title="Distibución de Cantidad de Ambientes",xlabel="Cantidad de Ambientes",ylabel="Ocurrencias")
p
# Out:
#   Input In [1629]
#     plt.shot"w()
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
# sns.histplot(data=ds_properati['property_bedrooms'], alpha = 0.5, binwidth=1).set(title="Distribución de Cantidad de Dormitorios",xlabel="Cantidad de Dormitorios",ylabel="Ocurrencias")

# %% [markdown]
# Como se puede observar para dormitorios, hay algunas propiedades que cuentan con un valor de -1 ya que, de otra forma, no figuraría en el histograma

# %%
ds_properati = ds_properati[ds_properati['property_bedrooms'] >= 0]

# %%
# sns_hist = sns.histplot(data=ds_properati['property_bedrooms'], alpha = 0.5, binwidth=1).set(title="Distribución de Cantidad de Dormitorios",xlabel="Cantidad de Dormitorios",ylabel="Ocurrencias")

# %% [markdown]
# #### Busqueda Valores Atípicos - Multivariado

# %%
ds_properati.reset_index(inplace=True, drop=True)

# %%
#sns.pairplot(ds_properati, hue="property_type", corner=True)

# %% [markdown]
# ##### Outliers relacionando la latitud y longitud
#
# Haciendo el analisis de los datos faltantes pudimos identificar a todos los registros donde su latitud y longitud no correspondía con la Capital Federal, por lo que no se encuentran outliers en este análisis.

# %%
plt.scatter(ds_properati.longitud, ds_properati.latitud)
plt.title('Dispersograma Longitud vs Latitud')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()

# %% [markdown]
# Como es de esperarse, la abrumadora mayoría de puntos se hallan conglomerados en un área. No se observan outliers en el gráfico (los mismos, al no ser puntos de Capital Federal fueron eliminados con anterioridad).

# %% [markdown]
# ##### Outliers relacionando ambientes y dormitorios, superficie cubierta y superficie total
#
# Para empezar, se eliminan aquellas entradas que tengan más dormitorios que ambientes (debido a que un dormitorio cuenta como un ambiente), y aquellas que tengan más superficie cubierta que total.

# %%
ds_properati = ds_properati[ds_properati['property_bedrooms'] <= ds_properati['property_rooms']]
ds_properati = ds_properati[ds_properati['property_surface_covered'] <= ds_properati['property_surface_total']]

# %%
plt.scatter(ds_properati.property_rooms, ds_properati.property_bedrooms)
plt.title('Dispersograma Ambientes vs Dormitorios')
plt.xlabel('Ambientes')
plt.ylabel('Dormitorios')
plt.show()

# %% [markdown]
# ACA SI HAY OUTLIER!!!!!!! Q ONDA?

# %% [markdown]
# Se observa que el scatter plot de Ambientes VS Dormitorios presenta un equilibrio, y a simple vista no se detectan outliers

# %%
plt.scatter(ds_properati.property_surface_total, ds_properati.property_surface_covered)
plt.title('Dispersograma Superficie Total vs Superficie Cubierta')
plt.xlabel('Superficie Total')
plt.ylabel('Superficie Cubierta')
plt.show()

# %% [markdown]
# A partir de los 300m² de superficie total, los puntos comienzan a estar mas dispersos, observando algunos posibles outlier para algunos puntos con más de 500m² de superficie total.

# %% [markdown]
# Se pueden observar potenciales outliers en la relación entre superficie total y superficie cubierta, por lo que se calcula la distancia de Mahalanobis para cada una de las observaciones.

# %%
posibles_ouliers = ds_properati.loc[ds_properati.property_surface_total > 500]
posibles_ouliers.head()
# Out:
#       created_on    latitud   longitud        provincia      barrio operation  \
# 952   2021-05-18 -34.619962 -58.524491  Capital Federal  VILLA REAL     Venta
# 1604  2021-07-31 -34.649667 -58.387365  Capital Federal    BARRACAS     Venta
# 2323  2021-03-15 -34.551708 -58.485867  Capital Federal    SAAVEDRA     Venta
# 2429  2021-10-01 -34.554993 -58.445175  Capital Federal    BELGRANO     Venta
# 2432  2021-10-01 -34.670847 -58.501121  Capital Federal   MATADEROS     Venta
#
#      property_type  property_rooms  property_bedrooms  property_surface_total  \
# 952           Casa             8.0                5.0                   570.0
# 1604          Casa             4.0                3.0                   538.0
# 2323          Casa             7.0                4.0                   522.0
# 2429          Casa             8.0                6.0                   560.0
# 2432          Casa             5.0                4.0                   522.0
#
#       property_surface_covered  property_price property_currency
# 952                      330.0        650000.0               USD
# 1604                     266.0        285000.0               USD
# 2323                     442.0        550000.0               USD
# 2429                     236.0        450000.0               USD
# 2432                     297.0        380000.0               USD

# %%
posibles_ouliers.property_type.unique()
# Out:
# array(['Casa'], dtype=object)

# %% [markdown]
# Como todas las observaciones son de tipo "Casa" consideramos que podría tratarse de quintas o campos por lo que no eliminamos los registros.

# %% [markdown]
# Distancia de mahalanobis:
# Es una medida de distancia entre el punto $\vec{x}$ y un conjunto de observaciones con media $\vec{\mu}$ y una matriz de covarianza $\Sigma$ .
#
# $d_{m}({\vec {x}},{\vec {\mu}})={\sqrt {({\vec {x}}-{\vec {\mu}})^{T}\Sigma ^{-1}({\vec {x}}-{\vec {\mu}})}}$
#
# El cálculo de la distancia de Mahalanobis equivale a:
#
# - Trasladar los datos de forma que su nueva media sea el origen de coordenadas.
# - Rotarlos para que las correlaciones entre las variables sean todas iguales a cero.
# - Estandarizar el resultado del paso anterior para que todas las varianzas valgan uno. Así se consigue una distancia que no depende de las unidades de medida, o de si las magnitudes de las variables son muy diferentes entre sí.
# - Calcular la distancia (euclídea) al origen de los puntos resultantes.

# %%
# vmedias=np.mean(ds_properati[['property_surface_total','property_surface_covered']])

# #Calculo la diferencia entre las observaciones y el vector de medias
# x_dif = ds_properati[['property_surface_total','property_surface_covered']] - vmedias

# #Calculo matriz de covarianza y su inversa
# cov=ds_properati[['property_surface_total','property_surface_covered']].cov().values
# inv_cov = np.linalg.inv(cov)

# #Calculamos el cuadrado de la distancia de mahalanobis
# mahal = np.dot( np.dot(x_dif, inv_cov) , x_dif.T)

# distancias = mahal.diagonal()

# %%
#sns.boxplot(distancias)

# %%
#pd.Series(np.sort(distancias))

# %% [markdown]
# Tenemos que seleccionar un valor umbral para definir qué observaciones podrían ser anómalas según la distancia de mahalanobis.

# %%
#############umbral

# %% [markdown]
# ##### Analisis de outliers relacionando la superficie total y el precio de la propiedad

# %% [markdown]
# -ACLARACION: Se hacen graficos como ayuda para la busqueda de outliers. Por lo general los puntos mas dispersos son considerados outliers, pero escoger unicamente a estos puntos como outliers no es una buena practica, por lo que el analisis sobre los graficos es mas detallados y analiza puntos con valores ilogicos o fuera de lugar por mas que esten dispersos de la media o no.

# %%
plt.scatter(ds_properati.property_surface_total, ds_properati.property_price)
plt.title('Dispersograma Superficie Total vs Precio de la propiedad')
plt.xlabel('Superficie Total')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# Se observa uniformidad en la distribucion de los puntos, los mismos se dispersan en mayor proporcion en la medida en que la superficie total aumenta. Los puntos mas dispersos son importancia para el analisis de outliers. En la próxima sección se tratarán estos.

# %% [markdown]
# ##### Análisis de outliers relacionando la superficie total cubierta de una propiedad con los precios de la misma

# %%
plt.scatter(ds_properati.property_surface_covered, ds_properati.property_price)
plt.title('Dispersograma Superficie cubierta vs Precio de la propiedad')
plt.xlabel('Superficie total cubierta')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# Se observa uniformidad en la distribucion de puntos, los mismos se dispersan en le medida que aumanta la superficie total cubierta. Se observan posibles outliers en los puntos con precio nulo, y aquellos puntos que esten sobre una franja vertical, en la que para un mismo valor de superficie total cubierta hayan precios muy elevados en comparacion al resto.

# %%
ds_properati.loc["property_price"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'property_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/tomas/Escritorio/Facultad/Orga_De_Datos/TP1/7506R_TP1_GRUPO06_ENTREGA_N1.ipynb Celda 262 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/tomas/Escritorio/Facultad/Orga_De_Datos/TP1/7506R_TP1_GRUPO06_ENTREGA_N1.ipynb#Y633sZmlsZQ%3D%3D?line=0'>1</a> ds_properati.loc["property_price"]
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:4057, in NDFrame.xs(self, key, axis, level, drop_level)
#    4055             new_index = index[loc]
#    4056 else:
# -> 4057     loc = index.get_loc(key)
#    4059     if isinstance(loc, np.ndarray):
#    4060         if loc.dtype == np.bool_:
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'property_price'

# %% [markdown]
# ##### Análisis de outliers relacionando la cantidad de dormitorios y el precio de cada propiedad

# %%
plt.scatter(ds_properati.property_bedrooms, ds_properati.property_price)
plt.title('Dispersograma Dormitorios vs Precio de la propiedad')
plt.xlabel('Dormitorios')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# Para cada cantidad de dormitorios se observa una dispersion unforme de los puntos, resaltando los puntos que se encuentran muy separados al resto. Los mismos son de importancia para el estudio de outliers como los valores con precio nulo.

# %%
##Tarda una barbaridad en ejecutarse.
plt.bar(ds_properati.property_bedrooms, ds_properati.property_price)
plt.title('Grafico de barras Dormitorios vs Precio de la propiedad')
plt.xlabel('Dormitorios')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# ##### Análisis outliers relacionando la cantidad de ambientes con el precio de la propiedad

# %%
plt.scatter(ds_properati.property_rooms, ds_properati.property_price)
plt.title('Dispersograma Ambientes vs Precio de la propiedad')
plt.xlabel('Ambientes')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# Para cada cantidad de ambientes se observa una dispersion uniforme de los puntos, resaltando los puntos que se encuentran muy separados al resto. Los mismos son de importancia para el estudio de outliers como los valores con precio nulo.

# %%
plt.bar(ds_properati.property_rooms, ds_properati.property_price)
plt.title('Grafico de barras Ambientes vs Precio de la propiedad')
plt.xlabel('Ambientes')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# ##### Análisis latitud y precio
#
# No resulta util para el analisis, no es representativo. Una misma latitud puede hacer referencia a varios barrios de la ciudad, por lo tanto el precio va a variar, habiendo outliers en un scatterplot. Sin embargo esto no quiere decir que sean outliers.

# %%
plt.scatter(ds_properati.latitud, ds_properati.property_price)
plt.title('Dispersograma Latitud vs Precio de la propiedad')
plt.xlabel('Latitutd')
plt.ylabel('Precio de la propiedad')
plt.show()

# %% [markdown]
# ##### Analisis de outliers relacionando la longitud con el precio de la propiedad

# %% [markdown]
# No resulta util para el analisis, no es representativo. Una misma longitud puede hacer referencia a varios barrios de la ciudad, por lo tanto el precio va a variar, habiendo outliers en un scatterplot. Sin embargo esto no quiere decir que sean outliers.

# %%
plt.scatter(ds_properati.longitud, ds_properati.property_price)
plt.title('Dispersograma Longitud vs Precio de la propiedad')
plt.xlabel('Longitud')
plt.ylabel('Precio de la propiedad')
plt.show()

# %%
eliminar = ds_properati[(ds_properati['property_price'] == 0)].index

# %% [markdown]
# Analizando outliers se observaron frecuentemente porpiedades con precio nulo, el criterio adoptado para las mismas es eliminarlas, ya que al tener precio nulo no aportan informacion de interes.

# %%
eliminar = ds_properati[(ds_properati['property_price'] == 0)].index
ds_properati.drop(eliminar, inplace = True)

# %% [markdown]
# ##### Análisis de outliers relacionando los dormiotorios con la superficie cubierta

# %%
plt.scatter(ds_properati.property_bedrooms, ds_properati.property_surface_covered)
plt.title('Dispersograma Dormitorios vs superficie cubierta')
plt.xlabel('Dormitorios')
plt.ylabel('Superficie cubierta')
plt.show()

# %% [markdown]
# Para cada cantidad de dormitorios se observa una dispersion uniforme de los puntos. Se observan outliers en los puntos mas dispersos del grafico (como la propiedad con un dormitorio y 500 de superficie cubierta), y aquellas propiedades con dormitorios y 0 de superficie cubierta.

# %%
plt.bar(ds_properati.property_bedrooms, ds_properati.property_surface_covered)
plt.title('Grafico de barras Dormitorios vs superficie cubierta')
plt.xlabel('Dormitorios')
plt.ylabel('Superficie cubierta')
plt.show()

# %% [markdown]
# ##### Análisis de outliers relacionando los ambientes con la superficie cubierta

# %%
plt.scatter(ds_properati.property_rooms, ds_properati.property_surface_covered)
plt.title('Dispersograma Ambientes vs superficie cubierta')
plt.xlabel('Ambientes')
plt.ylabel('Superficie cubierta')
plt.show()

# %% [markdown]
# Para cada cantidad de dormitorios se observa una dispersion uniforme de los puntos. Se observan outliers en los puntos mas dispersos del graficos (como la propiedad con un dormitorio y 500 de superficie cubierta), y aquellas propiedades con dormitorios y 0 de superficie cubierta.

# %%
plt.bar(ds_properati.property_rooms, ds_properati.property_surface_covered)
plt.title('Grafico de barras Ambientes vs superficie cubierta')
plt.xlabel('Ambientes')
plt.ylabel('Superficie cubierta')
plt.show()

# %% [markdown]
# ##### Análisis de outliers relacioando los dormitorios con la superficie total

# %%
plt.scatter(ds_properati.property_bedrooms, ds_properati.property_surface_total)
plt.title('Dispersograma Dormitorios vs superficie total')
plt.xlabel('Dormitorios')
plt.ylabel('Superficie total')
plt.show()

# %% [markdown]
# Outliers en los puntos mas dispersos del grupo (como la propiedad con un dormitorio y mas de 500 metros cuadrados de superficie total). Se observa que para aquellos puntos con 1 dormitorio hay algunos de ellos con 0 metros cuadrados de superficie total, lo cual debe ser analizado.

# %%
plt.bar(ds_properati.property_bedrooms, ds_properati.property_surface_total)
plt.title('Grafico de barras Dormitorios vs superficie total')
plt.xlabel('Dormitorios')
plt.ylabel('Superficie total')
plt.show()

# %% [markdown]
# ##### Análisis de outliers relacionando las habitaciones con la superficie total

# %%
plt.scatter(ds_properati.property_rooms, ds_properati.property_surface_total)
plt.title('Dispersograma Ambientes vs Superficie Total')
plt.xlabel('Ambientes')
plt.ylabel('Superficie total')
plt.show()

# %% [markdown]
# Al igual que en el resto de graficos, se observan outliers en los puntos mas dispersos del grafico. Sobre ellos se puede hablar paricularmente sobre aquellos puntos cuyo valor de Ambientes sea mayor a 10 (uno que es bsatante visible es el punto que representa a una propiedad de mas de 14 ambientes).
#
# Se observa tambien propiedades con 0 ambientes y una superficie total (VER QUE HACER ACAAAAAA). De igual forma hay propiedsdes con alguna cantidad no nula de ambientes y 0 metros cuadrados de superficie total.

# %%
plt.bar(ds_properati.property_rooms, ds_properati.property_surface_total)
plt.title('Grafico de barras Ambientes vs Superficie Total')
plt.xlabel('Ambientes')
plt.ylabel('Superficie total')
plt.show()

# %% [markdown]
# #### Reducción de la dimensionalidad

# %% [markdown]
# Como podemos ver en el grafico de correlacion, las únicas dos categorias que se encuentran lo suficientemente correlacionadas para aplicarle el algoritmo de reduccion de la dimensionalidad son property_surface_covered, property_surface_total y property_rooms, property_bedrooms

# %%
plt.figure(figsize = (15,8))
sns.heatmap(matriz_corr, annot = True, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Importamos las librerias a utilizar

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/tomas/anaconda3/lib/python3.8/site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/tomas/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/tomas/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/tomas/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.5.0)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ##### PCA
# Procedimiento matemático por el cual se transforma un conjunto de variables correlacionadas en un conjunto de variables no correlacionadas de menor dimensión. Estas nuevas variables se obtiene a partir de combinaciones lineales de las variables originales.
# Estas nuevas variables son las que se denominan Componentes Principales.
#
# Esta técnica intenta hallar aquellas combinaciones lineales de las variables originales que maximizan la varianza (minimizan la pérdida de información original).
#
# Esta técnica no requiere supuestos por lo que puede aplicarse siempre (pero tendrá sentido si las variables originales están correlacionadas).
#
# El objetivo es reducir la dimensión del problema, es decir, descartar la información redundante.

# %% [markdown]
# PASOS:
# - Normalizar los atributos
# - Calcular la matriz de covarianza
# - Calcular autovalores y autovectores
# - Ordenar los autovalores por orden descendente para elegir las componentes a utilizar
# - Ordenar los autovectores en función del orden de los autovalores y armar la matriz de transformación

# %%
columnas_elegidas = ["property_rooms","property_bedrooms","property_surface_covered","property_surface_total"]
x = ds_properati.loc[:, columnas_elegidas].values
x = StandardScaler().fit_transform(x)

# %%
x_pca = PCA(random_state=0)
x_pca.fit(x)
# Out:
# PCA(random_state=0)

# %%
var_cumu = np.cumsum(x_pca.explained_variance_ratio_) * 100
k = np.argmax(var_cumu > 95)
print("El numero mínimo de componentes para explicar el 95% de la varianza es: " + str(k))
# Out:
# El numero mínimo de componentes para explicar el 95% de la varianza es: 1

# %%
plt.figure(figsize=[10, 5])
plt.title('Varianza acumulada explicada por componente')
plt.ylabel('Varianza acumulada explicada')
plt.xlabel('Componentes principales')
plt.axvline(x=k, color="k", linestyle="--")
plt.axhline(y=95, color="r", linestyle="--")
ax = plt.plot(var_cumu)
plt.show()

# %% [markdown]
# Obtengo un modelo entrenado.

# %%
pca = PCA(n_components=2, random_state=0) 
x_transformada = pca.fit_transform(x)

# %%
pca_df_aux = pd.DataFrame(data = x_transformada, columns = ['cp_1','cp_2'])

# %%
pca.get_covariance()
# Out:
# array([[0.99437295, 0.90168034, 0.7993687 , 0.78423614],
#        [0.90168034, 0.99398711, 0.8020895 , 0.78713884],
#        [0.7993687 , 0.8020895 , 1.00618585, 0.9128689 ],
#        [0.78423614, 0.78713884, 0.9128689 , 1.00553441]])

# %%
fig = plt.figure(figsize = (5,5))
ax= fig.add_subplot(1,1,1) 

ax.scatter(x=pca_df_aux['cp_1'],y = pca_df_aux['cp_2'])
ax.set_xlabel('Componente Principal  1', fontsize = 10)
ax.set_ylabel('Componente Principal  2', fontsize = 10)
ax.grid()

plt.show()

# %%
# target=pd.DataFrame((np.column_stack(ds_properati['target'])).tolist()).T
# df_properati_pca = pd.concat([pca_df_aux, target], axis = 1)
# df_properati_pca.columns= ['cp_1', 'cp_2','target']

# %% [markdown]
# Exportamos el último data set para usarlo durante el otro tramo del TP

# %%
ds_properati.to_csv("nueva_database_properati.csv")
